# %% [markdown]
# # CruisePlan Demo
#
# This notebook demonstrates the complete CruisePlan workflow using Python functions rather than CLI commands. Each section corresponds to a CLI subcommand and shows how to accomplish the same tasks programmatically.
#
# ## Workflow Overview
#
# The data preparation phase includes steps 1 and 2, the cruise configuration is steps 3 and 4, and the scheduling is step 5.
#
# 1. **Bathymetry**: Get bathymetry data for depth calculations
# 2. **Pangaea**: Search PANGAEA database for relevant oceanographic datasets
# 3. **Stations**: Interactive station planning (or programmatic configuration)
# 4. **Process**: Enrich configuration with depths/coordinates + validate
# 5. **Schedule**: Generate cruise timeline and outputs
#
# All outputs will be saved to `tests_output/demo/` for easy exploration.

# %% [markdown]
# ## Setup and Imports

# %%
# Core imports
import logging
from pathlib import Path

import xarray as xr

from cruiseplan import bathymetry, pangaea, process, schedule
from cruiseplan.utils.global_ports import (
    add_custom_port,
    get_available_ports,
    list_ports_in_region,
)
from cruiseplan.utils.yaml_io import save_yaml

# Set up output directory
output_dir = Path('../tests_output/demo')
output_dir.mkdir(parents=True, exist_ok=True)

print(f"Demo outputs will be saved to: {output_dir.absolute()}")

# Configure logging to see what's happening
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
# Out:
# Demo outputs will be saved to: /home/runner/work/cruiseplan/cruiseplan/notebooks/../tests_output/demo

# %% [markdown]
# ## Phase 1: Data Preparation
#
# ### Step 1: Download Bathymetry Data
#
# **CLI Equivalent**:
#
# ```bash
# cruiseplan bathymetry --bathy-source etopo2022
# ```
#
# First, we need bathymetry data for depth calculations and visualization.

# %%
# Initialize bathymetry manager with ETOPO2022 data
print("📥 Downloading bathymetry data...")
bathy_path = bathymetry(bathy_source="etopo2022")
# Out:
# INFO: =� Downloading etopo2022 bathymetry data to /home/runner/work/cruiseplan/cruiseplan/data/bathymetry
# 📥 Downloading bathymetry data...
# Downloading ETOPO dataset to /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc...
# Attempting download from: https://www.ngdc.noaa.gov/thredds/fileServer/global/ETOPO2022/60s/60s_bed_elev_netcdf/ETOPO_2022_v1_60s_N90W180_bed.nc
# Downloading ETOPO: 0.00B [00:00, ?B/s]
# Downloading ETOPO: 55.9kB [00:00, 548kB/s]
# Downloading ETOPO: 256kB [00:00, 1.36MB/s]
# Downloading ETOPO: 647kB [00:00, 2.42MB/s]
# Downloading ETOPO: 1.19MB [00:00, 3.56MB/s]
# Downloading ETOPO: 1.65MB [00:00, 3.87MB/s]
# Downloading ETOPO: 2.17MB [00:00, 4.26MB/s]
# Downloading ETOPO: 2.65MB [00:00, 4.38MB/s]
# Downloading ETOPO: 3.15MB [00:00, 4.49MB/s]
# Downloading ETOPO: 3.68MB [00:00, 4.67MB/s]
# Downloading ETOPO: 4.13MB [00:01, 4.58MB/s]
# Downloading ETOPO: 4.62MB [00:01, 4.61MB/s]
# Downloading ETOPO: 5.09MB [00:01, 4.58MB/s]
# Downloading ETOPO: 5.53MB [00:01, 4.49MB/s]
# Downloading ETOPO: 5.96MB [00:01, 4.39MB/s]
# Downloading ETOPO: 6.44MB [00:01, 4.45MB/s]
# Downloading ETOPO: 6.89MB [00:01, 4.42MB/s]
# Downloading ETOPO: 7.34MB [00:01, 4.38MB/s]
# Downloading ETOPO: 7.77MB [00:01, 4.33MB/s]
# Downloading ETOPO: 8.30MB [00:02, 4.56MB/s]
# Downloading ETOPO: 8.76MB [00:02, 4.52MB/s]
# Downloading ETOPO: 9.23MB [00:02, 4.52MB/s]
# Downloading ETOPO: 9.69MB [00:02, 4.49MB/s]
# Downloading ETOPO: 10.1MB [00:02, 4.45MB/s]
# Downloading ETOPO: 10.6MB [00:02, 4.42MB/s]
# Downloading ETOPO: 11.1MB [00:02, 4.45MB/s]
# Downloading ETOPO: 11.6MB [00:02, 4.75MB/s]
# Downloading ETOPO: 12.1MB [00:02, 4.75MB/s]
# Downloading ETOPO: 12.6MB [00:03, 4.65MB/s]
# Downloading ETOPO: 13.1MB [00:03, 4.70MB/s]
# Downloading ETOPO: 13.5MB [00:03, 4.62MB/s]
# Downloading ETOPO: 14.0MB [00:03, 4.53MB/s]
# Downloading ETOPO: 14.5MB [00:03, 4.68MB/s]
# Downloading ETOPO: 15.0MB [00:03, 4.65MB/s]
# Downloading ETOPO: 15.5MB [00:03, 4.59MB/s]
# Downloading ETOPO: 15.9MB [00:03, 4.53MB/s]
# Downloading ETOPO: 16.4MB [00:03, 4.59MB/s]
# Downloading ETOPO: 16.9MB [00:04, 4.52MB/s]
# Downloading ETOPO: 17.3MB [00:04, 4.48MB/s]
# Downloading ETOPO: 17.8MB [00:04, 4.42MB/s]
# Downloading ETOPO: 18.2MB [00:04, 4.37MB/s]
# Downloading ETOPO: 18.7MB [00:04, 4.39MB/s]
# Downloading ETOPO: 19.1MB [00:04, 4.36MB/s]
# Downloading ETOPO: 19.6MB [00:04, 4.55MB/s]
# Downloading ETOPO: 20.1MB [00:04, 4.53MB/s]
# Downloading ETOPO: 20.6MB [00:04, 4.52MB/s]
# Downloading ETOPO: 21.0MB [00:05, 4.45MB/s]
# Downloading ETOPO: 21.5MB [00:05, 4.60MB/s]
# Downloading ETOPO: 22.0MB [00:05, 4.50MB/s]
# Downloading ETOPO: 22.4MB [00:05, 4.42MB/s]
# Downloading ETOPO: 22.9MB [00:05, 4.36MB/s]
# Downloading ETOPO: 23.4MB [00:05, 4.54MB/s]
# Downloading ETOPO: 23.9MB [00:05, 4.68MB/s]
# Downloading ETOPO: 24.4MB [00:05, 4.61MB/s]
# Downloading ETOPO: 24.9MB [00:05, 4.64MB/s]
# Downloading ETOPO: 25.3MB [00:05, 4.60MB/s]
# Downloading ETOPO: 25.8MB [00:06, 4.50MB/s]
# Downloading ETOPO: 26.2MB [00:06, 4.46MB/s]
# Downloading ETOPO: 26.7MB [00:06, 4.40MB/s]
# Downloading ETOPO: 27.1MB [00:06, 4.34MB/s]
# Downloading ETOPO: 27.6MB [00:06, 4.34MB/s]
# Downloading ETOPO: 28.0MB [00:06, 4.37MB/s]
# Downloading ETOPO: 28.5MB [00:06, 4.38MB/s]
# Downloading ETOPO: 28.9MB [00:06, 4.35MB/s]
# Downloading ETOPO: 29.4MB [00:06, 4.49MB/s]
# Downloading ETOPO: 29.9MB [00:07, 4.51MB/s]
# Downloading ETOPO: 30.4MB [00:07, 4.58MB/s]
# Downloading ETOPO: 30.9MB [00:07, 4.54MB/s]
# Downloading ETOPO: 31.3MB [00:07, 4.55MB/s]
# Downloading ETOPO: 31.8MB [00:07, 4.45MB/s]
# Downloading ETOPO: 32.3MB [00:07, 4.48MB/s]
# Downloading ETOPO: 32.8MB [00:07, 4.51MB/s]
# Downloading ETOPO: 33.2MB [00:07, 4.51MB/s]
# Downloading ETOPO: 33.8MB [00:07, 4.66MB/s]
# Downloading ETOPO: 34.3MB [00:08, 4.78MB/s]
# Downloading ETOPO: 34.8MB [00:08, 4.72MB/s]
# Downloading ETOPO: 35.2MB [00:08, 4.61MB/s]
# Downloading ETOPO: 35.7MB [00:08, 4.53MB/s]
# Downloading ETOPO: 36.1MB [00:08, 4.54MB/s]
# Downloading ETOPO: 36.6MB [00:08, 4.62MB/s]
# Downloading ETOPO: 37.1MB [00:08, 4.59MB/s]
# Downloading ETOPO: 37.6MB [00:08, 4.63MB/s]
# Downloading ETOPO: 38.1MB [00:08, 4.59MB/s]
# Downloading ETOPO: 38.5MB [00:09, 4.57MB/s]
# Downloading ETOPO: 39.0MB [00:09, 4.48MB/s]
# Downloading ETOPO: 39.4MB [00:09, 4.47MB/s]
# Downloading ETOPO: 39.9MB [00:09, 4.44MB/s]
# Downloading ETOPO: 40.4MB [00:09, 4.46MB/s]
# Downloading ETOPO: 40.9MB [00:09, 4.67MB/s]
# Downloading ETOPO: 41.4MB [00:09, 4.60MB/s]
# Downloading ETOPO: 41.8MB [00:09, 4.48MB/s]
# Downloading ETOPO: 42.3MB [00:09, 4.48MB/s]
# Downloading ETOPO: 42.8MB [00:10, 4.55MB/s]
# Downloading ETOPO: 43.2MB [00:10, 4.54MB/s]
# Downloading ETOPO: 43.7MB [00:10, 4.60MB/s]
# Downloading ETOPO: 44.2MB [00:10, 4.64MB/s]
# Downloading ETOPO: 44.7MB [00:10, 4.56MB/s]
# Downloading ETOPO: 45.1MB [00:10, 4.50MB/s]
# Downloading ETOPO: 45.6MB [00:10, 4.46MB/s]
# Downloading ETOPO: 46.1MB [00:10, 4.54MB/s]
# Downloading ETOPO: 46.5MB [00:10, 4.51MB/s]
# Downloading ETOPO: 47.0MB [00:11, 4.55MB/s]
# Downloading ETOPO: 47.5MB [00:11, 4.54MB/s]
# Downloading ETOPO: 47.9MB [00:11, 4.44MB/s]
# Downloading ETOPO: 48.4MB [00:11, 4.48MB/s]
# Downloading ETOPO: 49.1MB [00:11, 4.98MB/s]
# Downloading ETOPO: 49.5MB [00:11, 4.86MB/s]
# Downloading ETOPO: 50.0MB [00:11, 4.75MB/s]
# Downloading ETOPO: 50.5MB [00:11, 4.66MB/s]
# Downloading ETOPO: 50.9MB [00:11, 4.64MB/s]
# Downloading ETOPO: 51.4MB [00:12, 4.55MB/s]
# Downloading ETOPO: 52.0MB [00:12, 4.84MB/s]
# Downloading ETOPO: 52.4MB [00:12, 4.74MB/s]
# Downloading ETOPO: 52.9MB [00:12, 4.67MB/s]
# Downloading ETOPO: 53.4MB [00:12, 4.57MB/s]
# Downloading ETOPO: 53.8MB [00:12, 4.51MB/s]
# Downloading ETOPO: 54.3MB [00:12, 4.44MB/s]
# Downloading ETOPO: 54.7MB [00:12, 4.37MB/s]
# Downloading ETOPO: 55.1MB [00:12, 4.36MB/s]
# Downloading ETOPO: 55.6MB [00:12, 4.38MB/s]
# Downloading ETOPO: 56.1MB [00:13, 4.50MB/s]
# Downloading ETOPO: 56.6MB [00:13, 4.64MB/s]
# Downloading ETOPO: 57.1MB [00:13, 4.63MB/s]
# Downloading ETOPO: 57.6MB [00:13, 4.59MB/s]
# Downloading ETOPO: 58.0MB [00:13, 4.50MB/s]
# Downloading ETOPO: 58.5MB [00:13, 4.48MB/s]
# Downloading ETOPO: 58.9MB [00:13, 4.49MB/s]
# Downloading ETOPO: 59.4MB [00:13, 4.34MB/s]
# Downloading ETOPO: 59.9MB [00:13, 4.48MB/s]
# Downloading ETOPO: 60.4MB [00:14, 4.58MB/s]
# Downloading ETOPO: 61.0MB [00:14, 4.92MB/s]
# Downloading ETOPO: 61.5MB [00:14, 4.85MB/s]
# Downloading ETOPO: 61.9MB [00:14, 4.74MB/s]
# Downloading ETOPO: 62.4MB [00:14, 4.63MB/s]
# Downloading ETOPO: 62.9MB [00:14, 4.55MB/s]
# Downloading ETOPO: 63.3MB [00:14, 4.56MB/s]
# Downloading ETOPO: 63.9MB [00:14, 4.69MB/s]
# Downloading ETOPO: 64.3MB [00:14, 4.60MB/s]
# Downloading ETOPO: 64.8MB [00:15, 4.52MB/s]
# Downloading ETOPO: 65.2MB [00:15, 4.50MB/s]
# Downloading ETOPO: 65.7MB [00:15, 4.57MB/s]
# Downloading ETOPO: 66.2MB [00:15, 4.53MB/s]
# Downloading ETOPO: 66.6MB [00:15, 4.52MB/s]
# Downloading ETOPO: 67.1MB [00:15, 4.50MB/s]
# Downloading ETOPO: 67.6MB [00:15, 4.57MB/s]
# Downloading ETOPO: 68.2MB [00:15, 4.95MB/s]
# Downloading ETOPO: 68.7MB [00:15, 4.83MB/s]
# Downloading ETOPO: 69.1MB [00:16, 4.74MB/s]
# Downloading ETOPO: 69.7MB [00:16, 4.80MB/s]
# Downloading ETOPO: 70.1MB [00:16, 4.69MB/s]
# Downloading ETOPO: 70.6MB [00:16, 4.59MB/s]
# Downloading ETOPO: 71.0MB [00:16, 4.50MB/s]
# Downloading ETOPO: 71.4MB [00:16, 4.39MB/s]
# Downloading ETOPO: 71.9MB [00:16, 4.43MB/s]
# Downloading ETOPO: 72.4MB [00:16, 4.47MB/s]
# Downloading ETOPO: 72.9MB [00:16, 4.46MB/s]
# Downloading ETOPO: 73.3MB [00:17, 4.41MB/s]
# Downloading ETOPO: 73.8MB [00:17, 4.49MB/s]
# Downloading ETOPO: 74.2MB [00:17, 4.49MB/s]
# Downloading ETOPO: 74.8MB [00:17, 4.60MB/s]
# Downloading ETOPO: 75.2MB [00:17, 4.55MB/s]
# Downloading ETOPO: 75.7MB [00:17, 4.45MB/s]
# Downloading ETOPO: 76.2MB [00:17, 4.68MB/s]
# Downloading ETOPO: 76.7MB [00:17, 4.59MB/s]
# Downloading ETOPO: 77.1MB [00:17, 4.52MB/s]
# Downloading ETOPO: 77.5MB [00:18, 4.43MB/s]
# Downloading ETOPO: 78.1MB [00:18, 4.60MB/s]
# Downloading ETOPO: 78.6MB [00:18, 4.63MB/s]
# Downloading ETOPO: 79.0MB [00:18, 4.57MB/s]
# Downloading ETOPO: 79.5MB [00:18, 4.58MB/s]
# Downloading ETOPO: 79.9MB [00:18, 4.47MB/s]
# Downloading ETOPO: 80.4MB [00:18, 4.37MB/s]
# Downloading ETOPO: 80.8MB [00:18, 4.36MB/s]
# Downloading ETOPO: 81.3MB [00:18, 4.34MB/s]
# Downloading ETOPO: 81.7MB [00:19, 4.45MB/s]
# Downloading ETOPO: 82.2MB [00:19, 4.40MB/s]
# Downloading ETOPO: 82.7MB [00:19, 4.52MB/s]
# Downloading ETOPO: 83.2MB [00:19, 4.56MB/s]
# Downloading ETOPO: 83.7MB [00:19, 4.65MB/s]
# Downloading ETOPO: 84.1MB [00:19, 4.54MB/s]
# Downloading ETOPO: 84.6MB [00:19, 4.45MB/s]
# Downloading ETOPO: 85.0MB [00:19, 4.40MB/s]
# Downloading ETOPO: 85.5MB [00:19, 4.53MB/s]
# Downloading ETOPO: 86.0MB [00:19, 4.52MB/s]
# Downloading ETOPO: 86.5MB [00:20, 4.56MB/s]
# Downloading ETOPO: 87.0MB [00:20, 4.58MB/s]
# Downloading ETOPO: 87.4MB [00:20, 4.54MB/s]
# Downloading ETOPO: 87.9MB [00:20, 4.44MB/s]
# Downloading ETOPO: 88.4MB [00:20, 4.48MB/s]
# Downloading ETOPO: 88.9MB [00:20, 4.58MB/s]
# Downloading ETOPO: 89.3MB [00:20, 4.49MB/s]
# Downloading ETOPO: 89.7MB [00:20, 4.40MB/s]
# Downloading ETOPO: 90.2MB [00:20, 4.46MB/s]
# Downloading ETOPO: 90.7MB [00:21, 4.47MB/s]
# Downloading ETOPO: 91.1MB [00:21, 4.43MB/s]
# Downloading ETOPO: 91.6MB [00:21, 4.39MB/s]
# Downloading ETOPO: 92.1MB [00:21, 4.44MB/s]
# Downloading ETOPO: 92.5MB [00:21, 4.44MB/s]
# Downloading ETOPO: 93.1MB [00:21, 4.65MB/s]
# Downloading ETOPO: 93.5MB [00:21, 4.65MB/s]
# Downloading ETOPO: 94.0MB [00:21, 4.54MB/s]
# Downloading ETOPO: 94.4MB [00:21, 4.44MB/s]
# Downloading ETOPO: 94.9MB [00:22, 4.48MB/s]
# Downloading ETOPO: 95.4MB [00:22, 4.46MB/s]
# Downloading ETOPO: 95.8MB [00:22, 4.43MB/s]
# Downloading ETOPO: 96.3MB [00:22, 4.50MB/s]
# Downloading ETOPO: 96.8MB [00:22, 4.50MB/s]
# Downloading ETOPO: 97.3MB [00:22, 4.54MB/s]
# Downloading ETOPO: 97.7MB [00:22, 4.59MB/s]
# Downloading ETOPO: 98.2MB [00:22, 4.55MB/s]
# Downloading ETOPO: 98.7MB [00:22, 4.47MB/s]
# Downloading ETOPO: 99.1MB [00:23, 4.53MB/s]
# Downloading ETOPO: 99.6MB [00:23, 4.50MB/s]
# Downloading ETOPO: 100MB [00:23, 4.57MB/s]
# Downloading ETOPO: 101MB [00:23, 4.59MB/s]
# Downloading ETOPO: 101MB [00:23, 4.63MB/s]
# Downloading ETOPO: 102MB [00:23, 4.53MB/s]
# Downloading ETOPO: 102MB [00:23, 4.53MB/s]
# Downloading ETOPO: 102MB [00:23, 4.54MB/s]
# Downloading ETOPO: 103MB [00:23, 4.51MB/s]
# Downloading ETOPO: 103MB [00:24, 4.43MB/s]
# Downloading ETOPO: 104MB [00:24, 4.36MB/s]
# Downloading ETOPO: 104MB [00:24, 4.40MB/s]
# Downloading ETOPO: 105MB [00:24, 4.46MB/s]
# Downloading ETOPO: 105MB [00:24, 4.49MB/s]
# Downloading ETOPO: 106MB [00:24, 4.52MB/s]
# Downloading ETOPO: 106MB [00:24, 4.43MB/s]
# Downloading ETOPO: 107MB [00:24, 4.39MB/s]
# Downloading ETOPO: 107MB [00:24, 4.40MB/s]
# Downloading ETOPO: 107MB [00:25, 4.41MB/s]
# Downloading ETOPO: 108MB [00:25, 4.41MB/s]
# Downloading ETOPO: 108MB [00:25, 4.49MB/s]
# Downloading ETOPO: 109MB [00:25, 4.45MB/s]
# Downloading ETOPO: 109MB [00:25, 4.54MB/s]
# Downloading ETOPO: 110MB [00:25, 4.55MB/s]
# Downloading ETOPO: 110MB [00:25, 4.52MB/s]
# Downloading ETOPO: 111MB [00:25, 4.60MB/s]
# Downloading ETOPO: 111MB [00:25, 4.51MB/s]
# Downloading ETOPO: 112MB [00:25, 4.46MB/s]
# Downloading ETOPO: 112MB [00:26, 4.43MB/s]
# Downloading ETOPO: 113MB [00:26, 4.35MB/s]
# Downloading ETOPO: 113MB [00:26, 4.28MB/s]
# Downloading ETOPO: 114MB [00:26, 4.72MB/s]
# Downloading ETOPO: 114MB [00:26, 4.70MB/s]
# Downloading ETOPO: 115MB [00:26, 4.65MB/s]
# Downloading ETOPO: 115MB [00:26, 4.71MB/s]
# Downloading ETOPO: 116MB [00:26, 4.65MB/s]
# Downloading ETOPO: 116MB [00:26, 4.56MB/s]
# Downloading ETOPO: 117MB [00:27, 4.57MB/s]
# Downloading ETOPO: 117MB [00:27, 4.53MB/s]
# Downloading ETOPO: 117MB [00:27, 4.51MB/s]
# Downloading ETOPO: 118MB [00:27, 4.60MB/s]
# Downloading ETOPO: 118MB [00:27, 4.53MB/s]
# Downloading ETOPO: 119MB [00:27, 4.59MB/s]
# Downloading ETOPO: 119MB [00:27, 4.54MB/s]
# Downloading ETOPO: 120MB [00:27, 4.68MB/s]
# Downloading ETOPO: 120MB [00:27, 4.63MB/s]
# Downloading ETOPO: 121MB [00:28, 4.64MB/s]
# Downloading ETOPO: 121MB [00:28, 4.54MB/s]
# Downloading ETOPO: 122MB [00:28, 4.50MB/s]
# Downloading ETOPO: 122MB [00:28, 4.55MB/s]
# Downloading ETOPO: 123MB [00:28, 4.64MB/s]
# Downloading ETOPO: 123MB [00:28, 4.58MB/s]
# Downloading ETOPO: 124MB [00:28, 4.54MB/s]
# Downloading ETOPO: 124MB [00:28, 4.47MB/s]
# Downloading ETOPO: 125MB [00:28, 4.41MB/s]
# Downloading ETOPO: 125MB [00:29, 4.44MB/s]
# Downloading ETOPO: 125MB [00:29, 4.41MB/s]
# Downloading ETOPO: 126MB [00:29, 4.44MB/s]
# Downloading ETOPO: 126MB [00:29, 4.55MB/s]
# Downloading ETOPO: 127MB [00:29, 4.52MB/s]
# Downloading ETOPO: 127MB [00:29, 4.43MB/s]
# Downloading ETOPO: 128MB [00:29, 4.37MB/s]
# Downloading ETOPO: 128MB [00:29, 4.39MB/s]
# Downloading ETOPO: 129MB [00:29, 4.34MB/s]
# Downloading ETOPO: 129MB [00:30, 4.39MB/s]
# Downloading ETOPO: 130MB [00:30, 4.43MB/s]
# Downloading ETOPO: 130MB [00:30, 4.45MB/s]
# Downloading ETOPO: 131MB [00:30, 4.67MB/s]
# Downloading ETOPO: 131MB [00:30, 4.64MB/s]
# Downloading ETOPO: 132MB [00:30, 4.74MB/s]
# Downloading ETOPO: 132MB [00:30, 4.65MB/s]
# Downloading ETOPO: 132MB [00:30, 4.54MB/s]
# Downloading ETOPO: 133MB [00:30, 4.50MB/s]
# Downloading ETOPO: 133MB [00:31, 4.51MB/s]
# Downloading ETOPO: 134MB [00:31, 4.45MB/s]
# Downloading ETOPO: 134MB [00:31, 4.70MB/s]
# Downloading ETOPO: 135MB [00:31, 4.69MB/s]
# Downloading ETOPO: 135MB [00:31, 4.68MB/s]
# Downloading ETOPO: 136MB [00:31, 4.74MB/s]
# Downloading ETOPO: 136MB [00:31, 4.67MB/s]
# Downloading ETOPO: 137MB [00:31, 4.58MB/s]
# Downloading ETOPO: 137MB [00:31, 4.50MB/s]
# Downloading ETOPO: 138MB [00:31, 4.39MB/s]
# Downloading ETOPO: 138MB [00:32, 4.50MB/s]
# Downloading ETOPO: 139MB [00:32, 4.56MB/s]
# Downloading ETOPO: 139MB [00:32, 4.58MB/s]
# Downloading ETOPO: 140MB [00:32, 4.58MB/s]
# Downloading ETOPO: 140MB [00:32, 4.54MB/s]
# Downloading ETOPO: 141MB [00:32, 4.62MB/s]
# Downloading ETOPO: 141MB [00:32, 4.54MB/s]
# Downloading ETOPO: 142MB [00:32, 4.49MB/s]
# Downloading ETOPO: 142MB [00:32, 4.45MB/s]
# Downloading ETOPO: 142MB [00:33, 4.46MB/s]
# Downloading ETOPO: 143MB [00:33, 4.48MB/s]
# Downloading ETOPO: 143MB [00:33, 4.48MB/s]
# Downloading ETOPO: 144MB [00:33, 4.41MB/s]
# Downloading ETOPO: 144MB [00:33, 4.37MB/s]
# Downloading ETOPO: 145MB [00:33, 4.48MB/s]
# Downloading ETOPO: 145MB [00:33, 4.49MB/s]
# Downloading ETOPO: 146MB [00:33, 4.41MB/s]
# Downloading ETOPO: 146MB [00:33, 4.35MB/s]
# Downloading ETOPO: 147MB [00:34, 4.33MB/s]
# Downloading ETOPO: 147MB [00:34, 4.28MB/s]
# Downloading ETOPO: 147MB [00:34, 4.39MB/s]
# Downloading ETOPO: 148MB [00:34, 4.57MB/s]
# Downloading ETOPO: 148MB [00:34, 4.48MB/s]
# Downloading ETOPO: 149MB [00:34, 4.62MB/s]
# Downloading ETOPO: 150MB [00:34, 4.93MB/s]
# Downloading ETOPO: 150MB [00:34, 5.12MB/s]
# Downloading ETOPO: 151MB [00:34, 5.00MB/s]
# Downloading ETOPO: 151MB [00:35, 4.90MB/s]
# Downloading ETOPO: 152MB [00:35, 4.79MB/s]
# Downloading ETOPO: 152MB [00:35, 4.68MB/s]
# Downloading ETOPO: 152MB [00:35, 4.63MB/s]
# Downloading ETOPO: 153MB [00:35, 4.81MB/s]
# Downloading ETOPO: 153MB [00:35, 4.70MB/s]
# Downloading ETOPO: 154MB [00:35, 4.66MB/s]
# Downloading ETOPO: 154MB [00:35, 4.55MB/s]
# Downloading ETOPO: 155MB [00:35, 4.50MB/s]
# Downloading ETOPO: 155MB [00:36, 4.59MB/s]
# Downloading ETOPO: 156MB [00:36, 4.56MB/s]
# Downloading ETOPO: 156MB [00:36, 4.54MB/s]
# Downloading ETOPO: 157MB [00:36, 4.47MB/s]
# Downloading ETOPO: 157MB [00:36, 4.41MB/s]
# Downloading ETOPO: 158MB [00:36, 4.44MB/s]
# Downloading ETOPO: 158MB [00:36, 4.46MB/s]
# Downloading ETOPO: 159MB [00:36, 4.41MB/s]
# Downloading ETOPO: 159MB [00:36, 4.42MB/s]
# Downloading ETOPO: 159MB [00:37, 4.40MB/s]
# Downloading ETOPO: 160MB [00:37, 4.41MB/s]
# Downloading ETOPO: 160MB [00:37, 4.42MB/s]
# Downloading ETOPO: 161MB [00:37, 4.34MB/s]
# Downloading ETOPO: 161MB [00:37, 4.30MB/s]
# Downloading ETOPO: 162MB [00:37, 4.38MB/s]
# Downloading ETOPO: 162MB [00:37, 4.63MB/s]
# Downloading ETOPO: 163MB [00:37, 4.53MB/s]
# Downloading ETOPO: 163MB [00:37, 4.57MB/s]
# Downloading ETOPO: 164MB [00:37, 4.50MB/s]
# Downloading ETOPO: 164MB [00:38, 4.55MB/s]
# Downloading ETOPO: 165MB [00:38, 4.62MB/s]
# Downloading ETOPO: 165MB [00:38, 4.57MB/s]
# Downloading ETOPO: 166MB [00:38, 4.71MB/s]
# Downloading ETOPO: 166MB [00:38, 4.71MB/s]
# Downloading ETOPO: 167MB [00:38, 4.60MB/s]
# Downloading ETOPO: 167MB [00:38, 4.56MB/s]
# Downloading ETOPO: 167MB [00:38, 4.46MB/s]
# Downloading ETOPO: 168MB [00:38, 4.74MB/s]
# Downloading ETOPO: 169MB [00:39, 4.74MB/s]
# Downloading ETOPO: 169MB [00:39, 4.71MB/s]
# Downloading ETOPO: 170MB [00:39, 4.73MB/s]
# Downloading ETOPO: 170MB [00:39, 4.62MB/s]
# Downloading ETOPO: 170MB [00:39, 4.54MB/s]
# Downloading ETOPO: 171MB [00:39, 4.70MB/s]
# Downloading ETOPO: 172MB [00:39, 4.72MB/s]
# Downloading ETOPO: 172MB [00:39, 4.62MB/s]
# Downloading ETOPO: 172MB [00:39, 4.52MB/s]
# Downloading ETOPO: 173MB [00:40, 4.47MB/s]
# Downloading ETOPO: 173MB [00:40, 4.44MB/s]
# Downloading ETOPO: 174MB [00:40, 4.39MB/s]
# Downloading ETOPO: 174MB [00:40, 4.40MB/s]
# Downloading ETOPO: 175MB [00:40, 4.41MB/s]
# Downloading ETOPO: 175MB [00:40, 4.46MB/s]
# Downloading ETOPO: 176MB [00:40, 4.50MB/s]
# Downloading ETOPO: 176MB [00:40, 4.54MB/s]
# Downloading ETOPO: 177MB [00:40, 4.47MB/s]
# Downloading ETOPO: 177MB [00:41, 4.42MB/s]
# Downloading ETOPO: 178MB [00:41, 4.53MB/s]
# Downloading ETOPO: 178MB [00:41, 4.51MB/s]
# Downloading ETOPO: 178MB [00:41, 4.46MB/s]
# Downloading ETOPO: 179MB [00:41, 4.74MB/s]
# Downloading ETOPO: 179MB [00:41, 4.67MB/s]
# Downloading ETOPO: 180MB [00:41, 4.62MB/s]
# Downloading ETOPO: 180MB [00:41, 4.58MB/s]
# Downloading ETOPO: 181MB [00:41, 4.56MB/s]
# Downloading ETOPO: 181MB [00:42, 4.65MB/s]
# Downloading ETOPO: 182MB [00:42, 4.60MB/s]
# Downloading ETOPO: 182MB [00:42, 4.56MB/s]
# Downloading ETOPO: 183MB [00:42, 4.54MB/s]
# Downloading ETOPO: 183MB [00:42, 4.46MB/s]
# Downloading ETOPO: 184MB [00:42, 4.50MB/s]
# Downloading ETOPO: 184MB [00:42, 4.61MB/s]
# Downloading ETOPO: 185MB [00:42, 4.51MB/s]
# Downloading ETOPO: 185MB [00:42, 4.66MB/s]
# Downloading ETOPO: 186MB [00:43, 4.65MB/s]
# Downloading ETOPO: 186MB [00:43, 4.59MB/s]
# Downloading ETOPO: 187MB [00:43, 4.50MB/s]
# Downloading ETOPO: 187MB [00:43, 4.44MB/s]
# Downloading ETOPO: 187MB [00:43, 4.38MB/s]
# Downloading ETOPO: 188MB [00:43, 4.42MB/s]
# Downloading ETOPO: 188MB [00:43, 4.45MB/s]
# Downloading ETOPO: 189MB [00:43, 4.40MB/s]
# Downloading ETOPO: 189MB [00:43, 4.41MB/s]
# Downloading ETOPO: 190MB [00:44, 4.46MB/s]
# Downloading ETOPO: 190MB [00:44, 4.48MB/s]
# Downloading ETOPO: 191MB [00:44, 4.83MB/s]
# Downloading ETOPO: 191MB [00:44, 4.84MB/s]
# Downloading ETOPO: 192MB [00:44, 4.79MB/s]
# Downloading ETOPO: 192MB [00:44, 4.95MB/s]
# Downloading ETOPO: 193MB [00:44, 4.84MB/s]
# Downloading ETOPO: 193MB [00:44, 4.73MB/s]
# Downloading ETOPO: 194MB [00:44, 4.96MB/s]
# Downloading ETOPO: 194MB [00:44, 4.85MB/s]
# Downloading ETOPO: 195MB [00:45, 4.74MB/s]
# Downloading ETOPO: 195MB [00:45, 4.62MB/s]
# Downloading ETOPO: 196MB [00:45, 4.52MB/s]
# Downloading ETOPO: 196MB [00:45, 4.52MB/s]
# Downloading ETOPO: 197MB [00:45, 4.43MB/s]
# Downloading ETOPO: 197MB [00:45, 4.43MB/s]
# Downloading ETOPO: 198MB [00:45, 4.37MB/s]
# Downloading ETOPO: 198MB [00:45, 4.52MB/s]
# Downloading ETOPO: 199MB [00:45, 4.53MB/s]
# Downloading ETOPO: 199MB [00:46, 4.54MB/s]
# Downloading ETOPO: 200MB [00:46, 4.74MB/s]
# Downloading ETOPO: 200MB [00:46, 4.69MB/s]
# Downloading ETOPO: 201MB [00:46, 4.62MB/s]
# Downloading ETOPO: 201MB [00:46, 4.52MB/s]
# Downloading ETOPO: 201MB [00:46, 4.51MB/s]
# Downloading ETOPO: 202MB [00:46, 4.48MB/s]
# Downloading ETOPO: 202MB [00:46, 4.47MB/s]
# Downloading ETOPO: 203MB [00:46, 4.46MB/s]
# Downloading ETOPO: 203MB [00:47, 4.48MB/s]
# Downloading ETOPO: 204MB [00:47, 4.41MB/s]
# Downloading ETOPO: 204MB [00:47, 4.40MB/s]
# Downloading ETOPO: 205MB [00:47, 4.31MB/s]
# Downloading ETOPO: 205MB [00:47, 4.46MB/s]
# Downloading ETOPO: 206MB [00:47, 4.71MB/s]
# Downloading ETOPO: 206MB [00:47, 4.63MB/s]
# Downloading ETOPO: 207MB [00:47, 4.55MB/s]
# Downloading ETOPO: 207MB [00:47, 4.49MB/s]
# Downloading ETOPO: 208MB [00:48, 4.51MB/s]
# Downloading ETOPO: 208MB [00:48, 4.50MB/s]
# Downloading ETOPO: 208MB [00:48, 4.57MB/s]
# Downloading ETOPO: 209MB [00:48, 4.49MB/s]
# Downloading ETOPO: 209MB [00:48, 4.54MB/s]
# Downloading ETOPO: 210MB [00:48, 4.51MB/s]
# Downloading ETOPO: 210MB [00:48, 4.44MB/s]
# Downloading ETOPO: 211MB [00:48, 4.37MB/s]
# Downloading ETOPO: 211MB [00:48, 4.43MB/s]
# Downloading ETOPO: 212MB [00:49, 4.50MB/s]
# Downloading ETOPO: 212MB [00:49, 4.59MB/s]
# Downloading ETOPO: 213MB [00:49, 4.50MB/s]
# Downloading ETOPO: 213MB [00:49, 4.68MB/s]
# Downloading ETOPO: 214MB [00:49, 4.81MB/s]
# Downloading ETOPO: 214MB [00:49, 4.74MB/s]
# Downloading ETOPO: 215MB [00:49, 4.66MB/s]
# Downloading ETOPO: 215MB [00:49, 4.91MB/s]
# Downloading ETOPO: 216MB [00:49, 4.79MB/s]
# Downloading ETOPO: 216MB [00:50, 4.68MB/s]
# Downloading ETOPO: 217MB [00:50, 4.89MB/s]
# Downloading ETOPO: 217MB [00:50, 4.78MB/s]
# Downloading ETOPO: 218MB [00:50, 4.67MB/s]
# Downloading ETOPO: 218MB [00:50, 4.71MB/s]
# Downloading ETOPO: 219MB [00:50, 4.63MB/s]
# Downloading ETOPO: 219MB [00:50, 4.54MB/s]
# Downloading ETOPO: 220MB [00:50, 4.52MB/s]
# Downloading ETOPO: 220MB [00:50, 4.45MB/s]
# Downloading ETOPO: 220MB [00:50, 4.40MB/s]
# Downloading ETOPO: 221MB [00:51, 4.54MB/s]
# Downloading ETOPO: 221MB [00:51, 4.69MB/s]
# Downloading ETOPO: 222MB [00:51, 4.70MB/s]
# Downloading ETOPO: 222MB [00:51, 4.67MB/s]
# Downloading ETOPO: 223MB [00:51, 4.85MB/s]
# Downloading ETOPO: 224MB [00:51, 5.00MB/s]
# Downloading ETOPO: 224MB [00:51, 4.96MB/s]
# Downloading ETOPO: 225MB [00:51, 4.89MB/s]
# Downloading ETOPO: 225MB [00:51, 4.78MB/s]
# Downloading ETOPO: 225MB [00:52, 4.70MB/s]
# Downloading ETOPO: 226MB [00:52, 4.61MB/s]
# Downloading ETOPO: 226MB [00:52, 4.58MB/s]
# Downloading ETOPO: 227MB [00:52, 4.52MB/s]
# Downloading ETOPO: 227MB [00:52, 4.48MB/s]
# Downloading ETOPO: 228MB [00:52, 4.39MB/s]
# Downloading ETOPO: 228MB [00:52, 4.29MB/s]
# Downloading ETOPO: 229MB [00:52, 4.29MB/s]
# Downloading ETOPO: 229MB [00:52, 4.55MB/s]
# Downloading ETOPO: 230MB [00:53, 4.56MB/s]
# Downloading ETOPO: 230MB [00:53, 4.69MB/s]
# Downloading ETOPO: 231MB [00:53, 4.72MB/s]
# Downloading ETOPO: 231MB [00:53, 4.76MB/s]
# Downloading ETOPO: 232MB [00:53, 4.70MB/s]
# Downloading ETOPO: 232MB [00:53, 4.67MB/s]
# Downloading ETOPO: 233MB [00:53, 4.71MB/s]
# Downloading ETOPO: 233MB [00:53, 4.70MB/s]
# Downloading ETOPO: 234MB [00:53, 4.64MB/s]
# Downloading ETOPO: 234MB [00:54, 4.60MB/s]
# Downloading ETOPO: 235MB [00:54, 4.59MB/s]
# Downloading ETOPO: 235MB [00:54, 4.61MB/s]
# Downloading ETOPO: 235MB [00:54, 4.51MB/s]
# Downloading ETOPO: 236MB [00:54, 4.46MB/s]
# Downloading ETOPO: 236MB [00:54, 4.42MB/s]
# Downloading ETOPO: 237MB [00:54, 4.47MB/s]
# Downloading ETOPO: 237MB [00:54, 4.53MB/s]
# Downloading ETOPO: 238MB [00:54, 4.52MB/s]
# Downloading ETOPO: 238MB [00:55, 4.54MB/s]
# Downloading ETOPO: 239MB [00:55, 4.65MB/s]
# Downloading ETOPO: 239MB [00:55, 4.54MB/s]
# Downloading ETOPO: 240MB [00:55, 4.53MB/s]
# Downloading ETOPO: 456MB [01:45, 4.48MB/s]
# Downloading ETOPO: 456MB [01:45, 4.48MB/s]
# Downloading ETOPO: 456MB [01:45, 4.45MB/s]
# Downloading ETOPO: 457MB [01:45, 4.44MB/s]
# Downloading ETOPO: 457MB [01:45, 4.52MB/s]
# Downloading ETOPO: 458MB [01:45, 4.63MB/s]
# Downloading ETOPO: 458MB [01:45, 4.59MB/s]
# Downloading ETOPO: 459MB [01:45, 4.61MB/s]
# Downloading ETOPO: 459MB [01:45, 4.58MB/s]
# Downloading ETOPO: 460MB [01:46, 4.66MB/s]
# Downloading ETOPO: 460MB [01:46, 4.66MB/s]
# Downloading ETOPO: 461MB [01:46, 4.51MB/s]
# Downloading ETOPO: 461MB [01:46, 4.60MB/s]
# Downloading ETOPO: 462MB [01:46, 4.66MB/s]
# Downloading ETOPO: 462MB [01:46, 4.57MB/s]
# Downloading ETOPO: 463MB [01:46, 4.51MB/s]
# Downloading ETOPO: 463MB [01:46, 4.51MB/s]
# Downloading ETOPO: 464MB [01:46, 4.46MB/s]
# Downloading ETOPO: 464MB [01:47, 4.41MB/s]
# Downloading ETOPO: 465MB [01:47, 4.48MB/s]
# Downloading ETOPO: 465MB [01:47, 4.59MB/s]
# Downloading ETOPO: 466MB [01:47, 4.65MB/s]
# Downloading ETOPO: 466MB [01:47, 4.57MB/s]
# Downloading ETOPO: 466MB [01:47, 4.57MB/s]
# Downloading ETOPO: 467MB [01:47, 4.53MB/s]
# Downloading ETOPO: 467MB [01:47, 4.63MB/s]
# Downloading ETOPO: 468MB [01:47, 4.57MB/s]
# Downloading ETOPO: 468MB [01:48, 4.51MB/s]
# Downloading ETOPO: 469MB [01:48, 4.55MB/s]
# Download complete!

# %% [markdown]
# ### Step 2: Search PANGAEA Database
#
# **CLI Equivalent** (from root, rather than notebooks/ directory):
#
# ```bash
# cruiseplan pangaea "CTD" --lat 50 70 --lon -60 -30 --limit 5 --output-dir tests_output/demo --output demo`
# ```
#
# Search for relevant oceanographic datasets to inform our cruise planning.

# %%
print("🔍 Searching PANGAEA database and downloading station data...")

# Define search parameters
query = "CTD"  # or "CTD temperature North Atlantic"
lat_bounds = [50, 70]  # min_lat, max_lat
lon_bounds = [-60, -30]  # min_lon, max_lon
limit = 5

print(f"   Query: '{query}'")
print("   Geographic bounds: 50°N-70°N, 60°W-30°W")
print(f"   Limit: {limit} datasets")

# Search and download in one step
try:
    pangaea_stations, pangaea_files = pangaea(
        query_terms=query,
        lat_bounds=lat_bounds,
        lon_bounds=lon_bounds,
        max_results=limit,
        output_dir=str(output_dir),
        output="demo"
    )

    if pangaea_files:
        print("✅ PANGAEA processing completed!")
        for files in pangaea_files:
            print(f"   📄 {str(files)}")
    else:
        print("❌ No datasets found or processing failed")

except Exception as e:
    print(f"❌ PANGAEA processing failed: {e}")
# Out:
# 🔍 Searching PANGAEA database and downloading station data...
#    Query: 'CTD'
#    Geographic bounds: 50°N-70°N, 60°W-30°W
#    Limit: 5 datasets
# INFO: Failed to extract font properties from /usr/share/fonts/truetype/noto/NotoColorEmoji.ttf: Can not load face (unknown file format; error code 0x2)
# INFO: generated new fontManager
# INFO: 🔍 Searching PANGAEA for: 'CTD'
# INFO: 📍 Geographic bounds: lat [50, 70], lon [-60, -30]
# INFO: 🔍 Searching PANGAEA for: 'CTD'
# INFO: 📍 Geographic bounds: 50.00°N to 70.00°N, 60.00°W to 30.00°W
# INFO: Searching Pangaea: 'CTD' (Limit: 5)
# INFO: Search found 1823 total matches. Retrieving first 5...
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.755512
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604878
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604842
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604887
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604857
# INFO: ✓ Found 5 datasets with valid DOIs
# INFO: ✅ Found 5 datasets
# INFO: 📂 DOI file: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_dois.txt
# INFO: 📂 Stations file: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_stations.pkl
# INFO: ⚙️ Processing 5 DOIs...
# INFO: 🕐 Rate limit: 1.0 requests/second
# INFO: Starting fetch of 5 PANGAEA datasets
# INFO: 🕐 Rate limit: 1.0 requests/second
# INFO: [1/5] Fetching 10.1594/PANGAEA.755512
# INFO: [1/5] ✓ Retrieved dataset
# INFO: [2/5] Fetching 10.1594/PANGAEA.604878
# INFO: [2/5] ✓ Retrieved dataset
# INFO: [3/5] Fetching 10.1594/PANGAEA.604842
# INFO: [3/5] ✓ Retrieved dataset
# INFO: [4/5] Fetching 10.1594/PANGAEA.604887
# INFO: [4/5] ✓ Retrieved dataset
# INFO: [5/5] Fetching 10.1594/PANGAEA.604857
# INFO: [5/5] ✓ Retrieved dataset
# INFO: Merged 5 datasets into 2 campaigns
# INFO: Completed: 2 datasets from 5 DOIs
# INFO: Saved 2 datasets to: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_stations.pkl
# INFO: Summary:
# INFO:   - 5 datasets
# INFO:   - 2 unique campaigns
# INFO:   - 14 total events/stations
# INFO: ✅ PANGAEA processing completed successfully!
# INFO: 🚀 Next step: cruiseplan stations -p /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_stations.pkl
# ✅ PANGAEA processing completed!
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_dois.txt
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_stations.pkl

# %% [markdown]
# ## Phase 2: Cruise configuration
#
# ### Step 3: Create Station Configuration
#
# **CLI Equivalent**:
# ```bash
# cruiseplan stations --pangaea-file demo_stations.pkl --lat 50 70 --lon -60 -30`
# ```
#
# **BUT** for this demo, we'll create a programmatic station configuration rather than using the interactive interface.  Maybe we'll make an interactive demo to show the other options, but the interactive part runs nicely from the command line.

# %%
print("🗺️  Creating station configuration...")

# Create a sample cruise configuration
cruise_config = {
    'cruise_name': 'Demo North Atlantic Survey 2025',
    'default_vessel_speed': 10.0,
    'turnaround_time': 30.0,
    'ctd_descent_rate': 1.0,
    'ctd_ascent_rate': 1.0,
    'calculate_transfer_between_sections': True,
    'calculate_depth_via_bathymetry': True,
    'start_date': '2025-06-01T00:00:00Z',

    # Define stations along a transect
    'stations': [
        {
            'name': 'STN_001',
            'latitude': 55.0,
            'longitude': -50.0,
            'operation_type': 'CTD',
            'action': 'profile',
            'comment': 'Continental shelf station'
        },
        {
            'name': 'STN_002',
            'latitude': 57.0,
            'longitude': -45.0,
            'operation_type': 'CTD',
            'action': 'profile',
            'comment': 'Slope station'
        },
        {
            'name': 'STN_003',
            'latitude': 59.0,
            'longitude': -40.0,
            'operation_type': 'CTD',
            'action': 'profile',
            'comment': 'Deep water station'
        },
        {
            'name': 'STN_004',
            'latitude': 61.0,
            'longitude': -35.0,
            'operation_type': 'water_sampling',
            'action': 'sampling',
            'duration': 180.0,
            'comment': 'Water sampling station'
        },
        {
            'name': 'MOOR_001',
            'latitude': 60.5,
            'longitude': -38.0,
            'operation_type': 'mooring',
            'action': 'deployment',
            'duration': 240.0,
            'comment': 'Mooring deployment'
        },
        {
            'name': 'STN_005',
            'latitude': 63.0,
            'longitude': -30.0,
            'operation_type': 'CTD',
            'action': 'profile',
            'comment': 'Northern end station'
        },
        {
            'name': 'STN_006',
            'latitude': 58.0,
            'longitude': -42.0,
            'operation_type': 'CTD',
            'action': 'profile',
            'comment': 'Return transect station'
        }
    ],

    # Add scientific transit
    'transits': [
        {
            'name': 'Demo_ADCP_Survey',
            'operation_type': 'underway',
            'action': 'ADCP',
            'vessel_speed': 5.0,
            'route': [
                {'latitude': 56.0, 'longitude': -48.0},
                {'latitude': 56.0, 'longitude': -38.0}
            ],
            'comment': 'Zonal ADCP survey transect'
        }
    ],

    # Define execution order with leg-based port definitions
    'legs': [
        {
            'name': 'Demo_Survey',
            'departure_port': 'port_st_johns',
            'arrival_port': 'port_st_johns',
            'first_waypoint': 'STN_001',
            'last_waypoint': 'STN_006',
            'activities': ['STN_001', 'STN_002', 'STN_003', 'Demo_ADCP_Survey', 'STN_004', 'MOOR_001', 'STN_005', 'STN_006']
        }
    ]
}

# Save configuration
config_file = output_dir / "demo_cruise.yaml"
save_yaml(cruise_config, config_file)

print("✅ Station configuration created")
print(f"   Configuration saved to: {config_file}")
print(f"   Stations: {len(cruise_config['stations'])}")
print(f"   Transits: {len(cruise_config['transits'])}")
print(f"   Legs: {len(cruise_config['legs'])}")
# Out:
# INFO: Saved configuration to: ../tests_output/demo/demo_cruise.yaml
# 🗺️  Creating station configuration...
# ✅ Station configuration created
#    Configuration saved to: ../tests_output/demo/demo_cruise.yaml
#    Stations: 7
#    Transits: 1
#    Legs: 1

# %% [markdown]
# ### Step 3.5: Manually edit configuration
#
# The cruise configuration in `stations.yaml` will have some default values that need to be manually updated.  These include the `departure_port` and `arrival_port` within the cruise leg definition.  Default values are called "port_update", but can be replaced using values from the catalog of ports.
#
# ```yaml
# legs:
#   - name: Interactive_Survey
#     departure_port: port_update
#     arrival_port: port_update
#     first_waypoint: STN_001
#     last_waypoint: STN_002
#     strategy: sequential
#     activities:
#       - STN_001
#       - STN_002
#       - Transit_01
#       - Area_01
# ```

# %%
# Using cruiseplan.utils.global_ports with get_available_ports() and list_ports_in_region()

ports = get_available_ports()

# Display them nicely
for port_id, description in ports.items():
   print(f"{port_id}: {description}")

# Or get ports in a specific region
north_atlantic_ports = list_ports_in_region(
      min_lat=50.0, max_lat=70.0,
      min_lon=-30.0, max_lon=20.0
  )

for port_id, port_name in north_atlantic_ports.items():
    print(f"{port_id}: {port_name}")

# If you want to add a custom port for your project
add_custom_port("port_my_station", {
    "name": "My Research Station",
    "display_name": "My Research Station, Location",
    "latitude": 60.0,
    "longitude": -20.0,
    "timezone": "GMT+0",
    "description": "Custom research station for this cruise"
})
# Out:
# port_reykjavik: Iceland capital, subpolar/Nordic Seas
# port_nuuk: Greenland capital, Arctic research gateway
# port_tromso: Northern Norway, Arctic gateway
# port_trondheim: Central Norway, Norwegian Sea operations
# port_bergen: Western Norway, Nordic Seas
# port_southampton: UK south coast, Atlantic access
# port_bremerhaven: Germany, Arctic and Atlantic operations
# port_hamburg: Germany, North Sea and Baltic access
# port_emden: Germany, North Sea operations
# port_rostock: Germany, Baltic Sea operations
# port_kiel: Germany, Baltic Sea research hub
# port_brest: France, Atlantic operations
# port_nice: France, Mediterranean research
# port_vigo: Spain northwest, Atlantic margin research
# port_cadiz: Spain southwest, Atlantic and Mediterranean
# port_malaga: Spain south coast, Mediterranean research
# port_heraklion: Crete, Eastern Mediterranean research
# port_catania: Sicily, Mediterranean research
# port_limassol: Cyprus, Eastern Mediterranean operations
# port_las_palmas: Canary Islands, subtropical Atlantic research
# port_ponta_delgada: Azores, mid-Atlantic research hub
# port_funchal: Madeira, subtropical Atlantic operations
# port_mindelo: Cape Verde, tropical Atlantic research
# port_walvis_bay: Namibia, Benguela upwelling system
# port_durban: South Africa, Indian Ocean operations
# port_halifax: Nova Scotia, North Atlantic research hub
# port_st_johns: Newfoundland, Labrador Sea operations
# port_vancouver: British Columbia, North Pacific research
# port_woods_hole: Massachusetts, major oceanographic center
# port_san_diego: California, Pacific research operations
# port_astoria: Oregon, Pacific Northwest research
# port_honolulu: Hawaii, central Pacific research hub
# port_ensenada: Baja California, eastern Pacific research
# port_balboa: Panama, Pacific-Caribbean operations
# port_bridgetown: Barbados, Caribbean research hub
# port_rio_de_janeiro: Brazil, South Atlantic research
# port_fortaleza: Brazil northeast, equatorial Atlantic
# port_belem: Brazil, Amazon outflow studies
# port_recife: Brazil, tropical Atlantic research
# port_antofagasta: Chile, Humboldt current research
# port_port_louis_mauritius: Mauritius, western Indian Ocean research
# port_la_reunion: Reunion, southwestern Indian Ocean
# port_port_louis_seychelles: Seychelles, equatorial Indian Ocean
# port_colombo: Sri Lanka, northern Indian Ocean research
# port_singapore: Singapore, Southeast Asian research hub
# port_yokohama: Japan, western Pacific research
# port_fremantle: Western Australia, Indian Ocean research
# port_wellington: New Zealand, Southern Ocean research
# port_auckland: New Zealand, Southwest Pacific research
# port_papeete: French Polynesia, central Pacific research
# port_update: Default port for station picker - update with actual ports
# port_reykjavik: Reykjavik
# port_tromso: Tromsø
# port_trondheim: Trondheim
# port_bergen: Bergen
# port_southampton: Southampton
# port_bremerhaven: Bremerhaven
# port_hamburg: Hamburg
# port_emden: Emden
# port_rostock: Rostock
# port_kiel: Kiel
# port_update: Reykjavik (DEFAULT in stations.yaml)

# %% [markdown]
# ### Step 4: Process Configuration
#
# **CLI Equivalent**: `cruiseplan enrich -c demo_cruise.yaml --add-depths --add-coords --expand-sections`
#
# Add computed data like depths, formatted coordinates, and expand CTD sections.

# %%
print("🔧 Processing configuration (enrich + validate + map)...")
config_file = output_dir / "demo_cruise.yaml"

try:
    cruise_config, generated_config_files = process(
        config_file=config_file,
        output_dir=str(output_dir),
        output="demo_cruise",
        format="png",
        bathy_source="etopo2022",
        bathy_dir="../data/bathymetry",  # Go up to project root, then into data
        bathy_stride=10,
        figsize=[12, 8],
        depth_check=True,
        tolerance=10
    )

    if cruise_config:
        print("✅ Processing completed successfully!")
        print("   - Configuration enriched")
        print("   - Validation passed")
        for file in generated_config_files:
            print(f"   📄 {str(file)}")
    else:
        print("❌ Processing failed")

except Exception as e:
    print(f"❌ Processing failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# INFO: 🔧 Enriching cruise configuration...
# INFO: 🔧 Enriching /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise.yaml
# INFO: 📁 Output will be saved to: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# WARNING: ⚠️ Added missing field: default_distance_between_stations = 15.0 km
# INFO: ℹ️ Missing required fields added with defaults. Update these values as needed.
# INFO: Saved configuration to: /tmp/tmp0j8eq99y.yaml
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# 🔧 Processing configuration (enrich + validate + map)...
# INFO: Saved configuration to: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: ✅ Validating cruise configuration...
# INFO:  Validating /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: ✅ Validation passed
# INFO: 🗺️ Generating cruise maps...
# INFO: Display bounds: 42.6°-68.0°N, -57.7°--25.0°E
# INFO: Loading bathymetry for region: 39.6°-71.0°N, -60.7°--22.0°E
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: Added bathymetry contours covering full region
# INFO: Map displayed with 9 points, 1 lines, 0 areas
# INFO: Map saved to /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_map.png
# INFO: ✅ Processing workflow completed successfully!
# ✅ Processing completed successfully!
#    - Configuration enriched
#    - Validation passed
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_map.png

# %% [markdown]
# ## Phase 3: Cruise scheduling + outputs
#
# ### Step 5: Generate Schedule
#
# **CLI Equivalent**: `cruiseplan schedule -c demo_cruise_enriched.yaml -o tests_output/demo/ --format all`
#
# Generate the complete cruise timeline and output files.

# %%
for files in generated_config_files:
    if str(files).endswith('enriched.yaml'):
        enriched_config_file = output_dir / "demo_cruise_enriched.yaml"


print("📅 Generating cruise schedule...")

try:
    # Generate the schedule with multiple output formats using new API
    timeline, generated_files = schedule(
        config_file=enriched_config_file,
        output_dir="../tests_output/demo",
        output="demo_cruise",
        format="html,csv,netcdf",
        leg=None,
        derive_netcdf=True
    )

    print("✅ Schedule generated successfully!")
    if timeline:
        print(f"   Timeline object created with {len(timeline)} activities")
        print("   Output files in: ../tests_output/demo/")
        print("   Generated formats: HTML, CSV, NetCDF")
        for file in generated_files:
            print(f"   - {file}")

    else:
        print("⚠️ No timeline generated")

except Exception as e:
    print(f"❌ Schedule generation failed: {e}")
    # Optionally show the full traceback for debugging
    import traceback
    traceback.print_exc()
# Out:
# INFO: 📅 Generating schedule from /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: Processing leg 'Demo_Survey': Leg 'Demo_Survey': St. John's (round trip), 0 operations, 0 clusters
# INFO: Generated maritime timeline with 17 activities
# INFO: 🌐 HTML Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
# INFO:    Timeline contains 17 activities
# INFO: 🔍 HTML Generator: Processing 17 timeline activities
# INFO: ✅ Generated HTML schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
# INFO: 📊 CSV Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
# INFO:    Timeline contains 17 activities
# INFO: ✅ Generated CSV schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
# INFO: 📄 NetCDF Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO:    Timeline contains 17 activities
# INFO: Generating ship schedule NetCDF: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO: Ship schedule NetCDF written to: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO: ✅ Generated NetCDF schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO: 📅 Schedule generation complete! Generated 3 files
# 📅 Generating cruise schedule...
# ✅ Schedule generated successfully!
#    Timeline object created with 17 activities
#    Output files in: ../tests_output/demo/
#    Generated formats: HTML, CSV, NetCDF
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc

# %%
# Find the *.nc file in generated_files list of paths
schedule_file = None
for file in generated_files:
    if str(file).endswith('.nc'):
        schedule_file = file
        break
ds = xr.open_dataset(schedule_file)
ds
# Out:
# <xarray.Dataset> Size: 6kB
# Dimensions:         (obs: 17)
# Coordinates:
#     time            (obs) datetime64[ns] 136B ...
#     longitude       (obs) float32 68B ...
#     latitude        (obs) float32 68B ...
# Dimensions without coordinates: obs
# Data variables:
#     name            (obs) <U35 2kB ...
#     category        (obs) <U15 1kB ...
#     type            (obs) <U10 680B ...
#     action          (obs) <U10 680B ...
#     comment         (obs) <U1 68B ...
#     leg_assignment  (obs) <U11 748B ...
#     duration        (obs) float32 68B ...
#     vessel_speed    (obs) float32 68B ...
# Attributes:
#     featureType:          trajectory
#     title:                Ship Schedule: Demo North Atlantic Survey 2025
#     institution:          Generated by CruisePlan software
#     source:               Scheduler computation from YAML configuration
#     Conventions:          CF-1.8
#     cruise_name:          Demo North Atlantic Survey 2025
#     total_duration_days:  4.838511813431978e-10
#     creation_date:        2025-12-23T10:14:46

# %% [markdown]
# ## Workflow Summary
#
# Let's review what we've accomplished and check our output files.

# %%
all_files = pangaea_files + [config_file] + generated_config_files + generated_files

print("✅ CruisePlan Demo Complete!")
print(f"📁 Generated files: {len(all_files)} files in {Path(output_dir).name}/")
for file in all_files:
    print(f"   📄 {file.name}")
# Out:
# ✅ CruisePlan Demo Complete!
# 📁 Generated files: 8 files in demo/
#    📄 demo_dois.txt
#    📄 demo_stations.pkl
#    📄 demo_cruise.yaml
#    📄 demo_cruise_enriched.yaml
#    📄 demo_cruise_map.png
#    📄 demo_cruise_schedule.html
#    📄 demo_cruise_schedule.csv
#    📄 demo_cruise_schedule.nc
