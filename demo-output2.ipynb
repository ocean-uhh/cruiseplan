# %% [markdown]
# # CruisePlan Demo
#
# This notebook demonstrates the complete CruisePlan workflow using Python functions rather than CLI commands. Each section corresponds to a CLI subcommand and shows how to accomplish the same tasks programmatically.
#
# ## Workflow Overview
#
# The data preparation phase includes steps 1 and 2, the cruise configuration is steps 3 and 4, and the scheduling is step 5.
#
# 1. **Bathymetry**: Get bathymetry data for depth calculations
# 2. **Pangaea**: Search PANGAEA database for relevant oceanographic datasets
# 3. **Stations**: Interactive station planning (or programmatic configuration)
# 4. **Process**: Enrich configuration with depths/coordinates + validate
# 5. **Schedule**: Generate cruise timeline and outputs
#
# All outputs will be saved to `tests_output/demo/` for easy exploration.

# %% [markdown]
# ## Setup and Imports

# %%
# Core imports
import logging
from pathlib import Path

import xarray as xr

import cruiseplan
from cruiseplan.config.ports import (
    add_custom_port,
    get_available_ports,
    list_ports_in_region,
)
from cruiseplan.config.yaml_io import save_yaml

# Set up output directory
output_dir = Path("../tests_output/demo")
output_dir.mkdir(parents=True, exist_ok=True)

print(f"Demo outputs will be saved to: {output_dir.absolute()}")

# Configure logging to see what's happening
logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")
# Out:
# Demo outputs will be saved to: /home/runner/work/cruiseplan/cruiseplan/notebooks/../tests_output/demo

# %% [markdown]
# ## Phase 1: Data Preparation
#
# ### Step 1: Download Bathymetry Data
#
# **CLI Equivalent**:
#
# ```bash
# cruiseplan bathymetry --bathy-source etopo2022
# ```
#
# First, we need bathymetry data for depth calculations and visualization.

# %%
# Initialize bathymetry manager with ETOPO2022 data
print("📥 Downloading bathymetry data...")
bathy_result = cruiseplan.bathymetry(bathy_source="etopo2022")
bathy_path = bathy_result.data_file
# Out:
# INFO: 🌊 Downloading etopo2022 bathymetry data to /home/runner/work/cruiseplan/cruiseplan/data/bathymetry
# 📥 Downloading bathymetry data...
# Downloading ETOPO dataset to /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc...
# Attempting download from: https://www.ngdc.noaa.gov/thredds/fileServer/global/ETOPO2022/60s/60s_bed_elev_netcdf/ETOPO_2022_v1_60s_N90W180_bed.nc
# Downloading ETOPO: 0.00B [00:00, ?B/s]
# Downloading ETOPO: 112kB [00:00, 1.14MB/s]
# Downloading ETOPO: 432kB [00:00, 2.35MB/s]
# Downloading ETOPO: 0.99MB [00:00, 3.91MB/s]
# Downloading ETOPO: 1.88MB [00:00, 5.84MB/s]
# Downloading ETOPO: 2.69MB [00:00, 6.61MB/s]
# Downloading ETOPO: 3.43MB [00:00, 6.85MB/s]
# Downloading ETOPO: 4.25MB [00:00, 7.22MB/s]
# Downloading ETOPO: 5.05MB [00:00, 7.42MB/s]
# Downloading ETOPO: 5.79MB [00:00, 7.38MB/s]
# Downloading ETOPO: 6.67MB [00:01, 7.73MB/s]
# Downloading ETOPO: 7.41MB [00:01, 7.61MB/s]
# Downloading ETOPO: 8.14MB [00:01, 7.47MB/s]
# Downloading ETOPO: 8.86MB [00:01, 7.36MB/s]
# Downloading ETOPO: 9.59MB [00:01, 7.33MB/s]
# Downloading ETOPO: 10.3MB [00:01, 7.20MB/s]
# Downloading ETOPO: 11.1MB [00:01, 7.29MB/s]
# Downloading ETOPO: 11.9MB [00:01, 7.47MB/s]
# Downloading ETOPO: 12.7MB [00:01, 7.63MB/s]
# Downloading ETOPO: 13.5MB [00:02, 7.66MB/s]
# Downloading ETOPO: 14.3MB [00:02, 7.66MB/s]
# Downloading ETOPO: 15.2MB [00:02, 8.01MB/s]
# Downloading ETOPO: 15.9MB [00:02, 7.88MB/s]
# Downloading ETOPO: 16.7MB [00:02, 7.74MB/s]
# Downloading ETOPO: 17.4MB [00:02, 7.59MB/s]
# Downloading ETOPO: 18.2MB [00:02, 7.51MB/s]
# Downloading ETOPO: 19.2MB [00:02, 8.28MB/s]
# Downloading ETOPO: 20.1MB [00:02, 8.42MB/s]
# Downloading ETOPO: 20.9MB [00:02, 8.30MB/s]
# Downloading ETOPO: 21.8MB [00:03, 8.32MB/s]
# Downloading ETOPO: 22.6MB [00:03, 8.15MB/s]
# Downloading ETOPO: 23.4MB [00:03, 7.99MB/s]
# Downloading ETOPO: 24.1MB [00:03, 7.84MB/s]
# Downloading ETOPO: 24.9MB [00:03, 7.78MB/s]
# Downloading ETOPO: 25.8MB [00:03, 7.98MB/s]
# Downloading ETOPO: 26.6MB [00:03, 8.00MB/s]
# Downloading ETOPO: 27.4MB [00:03, 8.14MB/s]
# Downloading ETOPO: 28.3MB [00:03, 8.32MB/s]
# Downloading ETOPO: 29.1MB [00:04, 8.17MB/s]
# Downloading ETOPO: 30.2MB [00:04, 8.63MB/s]
# Downloading ETOPO: 31.0MB [00:04, 8.47MB/s]
# Downloading ETOPO: 31.8MB [00:04, 8.32MB/s]
# Downloading ETOPO: 32.6MB [00:04, 8.17MB/s]
# Downloading ETOPO: 33.4MB [00:04, 8.03MB/s]
# Downloading ETOPO: 34.1MB [00:04, 7.89MB/s]
# Downloading ETOPO: 34.9MB [00:04, 7.76MB/s]
# Downloading ETOPO: 35.6MB [00:04, 7.64MB/s]
# Downloading ETOPO: 36.4MB [00:05, 7.53MB/s]
# Downloading ETOPO: 37.1MB [00:05, 7.40MB/s]
# Downloading ETOPO: 37.8MB [00:05, 7.29MB/s]
# Downloading ETOPO: 38.5MB [00:05, 7.19MB/s]
# Downloading ETOPO: 39.2MB [00:05, 7.07MB/s]
# Downloading ETOPO: 39.9MB [00:05, 6.97MB/s]
# Downloading ETOPO: 40.5MB [00:05, 6.88MB/s]
# Downloading ETOPO: 41.2MB [00:05, 6.80MB/s]
# Downloading ETOPO: 41.9MB [00:05, 6.72MB/s]
# Downloading ETOPO: 42.5MB [00:05, 6.75MB/s]
# Downloading ETOPO: 43.2MB [00:06, 6.74MB/s]
# Downloading ETOPO: 43.9MB [00:06, 6.84MB/s]
# Downloading ETOPO: 44.7MB [00:06, 6.90MB/s]
# Downloading ETOPO: 45.4MB [00:06, 7.02MB/s]
# Downloading ETOPO: 46.1MB [00:06, 7.02MB/s]
# Downloading ETOPO: 46.9MB [00:06, 7.16MB/s]
# Downloading ETOPO: 47.6MB [00:06, 7.16MB/s]
# Downloading ETOPO: 48.3MB [00:06, 7.04MB/s]
# Downloading ETOPO: 49.0MB [00:06, 6.95MB/s]
# Downloading ETOPO: 49.6MB [00:07, 6.83MB/s]
# Downloading ETOPO: 50.3MB [00:07, 6.82MB/s]
# Downloading ETOPO: 51.0MB [00:07, 6.91MB/s]
# Downloading ETOPO: 51.7MB [00:07, 6.85MB/s]
# Downloading ETOPO: 52.4MB [00:07, 6.97MB/s]
# Downloading ETOPO: 53.1MB [00:07, 6.94MB/s]
# Downloading ETOPO: 53.8MB [00:07, 6.86MB/s]
# Downloading ETOPO: 54.5MB [00:07, 6.84MB/s]
# Downloading ETOPO: 55.2MB [00:07, 6.83MB/s]
# Downloading ETOPO: 55.8MB [00:07, 6.78MB/s]
# Downloading ETOPO: 56.5MB [00:08, 6.82MB/s]
# Downloading ETOPO: 57.2MB [00:08, 6.77MB/s]
# Downloading ETOPO: 57.9MB [00:08, 6.76MB/s]
# Downloading ETOPO: 58.6MB [00:08, 6.77MB/s]
# Downloading ETOPO: 59.3MB [00:08, 6.77MB/s]
# Downloading ETOPO: 60.0MB [00:08, 6.89MB/s]
# Downloading ETOPO: 60.7MB [00:08, 6.92MB/s]
# Downloading ETOPO: 61.4MB [00:08, 6.96MB/s]
# Downloading ETOPO: 62.1MB [00:08, 6.95MB/s]
# Downloading ETOPO: 62.8MB [00:09, 6.93MB/s]
# Downloading ETOPO: 63.5MB [00:09, 6.87MB/s]
# Downloading ETOPO: 64.2MB [00:09, 6.89MB/s]
# Downloading ETOPO: 64.9MB [00:09, 6.86MB/s]
# Downloading ETOPO: 65.6MB [00:09, 6.93MB/s]
# Downloading ETOPO: 66.3MB [00:09, 6.94MB/s]
# Downloading ETOPO: 67.0MB [00:09, 6.89MB/s]
# Downloading ETOPO: 67.7MB [00:09, 7.04MB/s]
# Downloading ETOPO: 68.4MB [00:09, 6.99MB/s]
# Downloading ETOPO: 69.1MB [00:09, 6.93MB/s]
# Downloading ETOPO: 69.8MB [00:10, 6.93MB/s]
# Downloading ETOPO: 70.5MB [00:10, 6.94MB/s]
# Downloading ETOPO: 71.2MB [00:10, 6.99MB/s]
# Downloading ETOPO: 72.0MB [00:10, 7.06MB/s]
# Downloading ETOPO: 72.7MB [00:10, 7.00MB/s]
# Downloading ETOPO: 73.3MB [00:10, 6.92MB/s]
# Downloading ETOPO: 74.1MB [00:10, 7.01MB/s]
# Downloading ETOPO: 74.8MB [00:10, 7.11MB/s]
# Downloading ETOPO: 75.5MB [00:10, 7.15MB/s]
# Downloading ETOPO: 76.2MB [00:11, 7.08MB/s]
# Downloading ETOPO: 76.9MB [00:11, 6.97MB/s]
# Downloading ETOPO: 77.6MB [00:11, 6.93MB/s]
# Downloading ETOPO: 78.3MB [00:11, 6.85MB/s]
# Downloading ETOPO: 79.0MB [00:11, 7.00MB/s]
# Downloading ETOPO: 79.7MB [00:11, 6.98MB/s]
# Downloading ETOPO: 80.4MB [00:11, 6.88MB/s]
# Downloading ETOPO: 81.1MB [00:11, 6.95MB/s]
# Downloading ETOPO: 81.8MB [00:11, 6.95MB/s]
# Downloading ETOPO: 82.6MB [00:12, 7.02MB/s]
# Downloading ETOPO: 83.2MB [00:12, 6.93MB/s]
# Downloading ETOPO: 83.9MB [00:12, 6.95MB/s]
# Downloading ETOPO: 84.7MB [00:12, 7.02MB/s]
# Downloading ETOPO: 85.4MB [00:12, 6.99MB/s]
# Downloading ETOPO: 86.1MB [00:12, 7.05MB/s]
# Downloading ETOPO: 86.8MB [00:12, 7.02MB/s]
# Downloading ETOPO: 87.5MB [00:12, 6.93MB/s]
# Downloading ETOPO: 88.2MB [00:12, 6.90MB/s]
# Downloading ETOPO: 88.9MB [00:12, 6.88MB/s]
# Downloading ETOPO: 89.6MB [00:13, 6.84MB/s]
# Downloading ETOPO: 90.2MB [00:13, 6.82MB/s]
# Downloading ETOPO: 90.9MB [00:13, 6.83MB/s]
# Downloading ETOPO: 91.7MB [00:13, 6.98MB/s]
# Downloading ETOPO: 92.4MB [00:13, 6.97MB/s]
# Downloading ETOPO: 93.0MB [00:13, 6.88MB/s]
# Downloading ETOPO: 93.7MB [00:13, 6.80MB/s]
# Downloading ETOPO: 94.4MB [00:13, 6.82MB/s]
# Downloading ETOPO: 95.1MB [00:13, 6.93MB/s]
# Downloading ETOPO: 95.8MB [00:14, 6.87MB/s]
# Downloading ETOPO: 96.5MB [00:14, 6.84MB/s]
# Downloading ETOPO: 97.2MB [00:14, 6.77MB/s]
# Downloading ETOPO: 97.9MB [00:14, 6.83MB/s]
# Downloading ETOPO: 98.6MB [00:14, 6.84MB/s]
# Downloading ETOPO: 99.2MB [00:14, 6.76MB/s]
# Downloading ETOPO: 99.9MB [00:14, 6.82MB/s]
# Downloading ETOPO: 101MB [00:14, 6.86MB/s]
# Downloading ETOPO: 101MB [00:14, 6.90MB/s]
# Downloading ETOPO: 102MB [00:14, 6.94MB/s]
# Downloading ETOPO: 103MB [00:15, 7.06MB/s]
# Downloading ETOPO: 103MB [00:15, 6.98MB/s]
# Downloading ETOPO: 104MB [00:15, 6.92MB/s]
# Downloading ETOPO: 105MB [00:15, 6.96MB/s]
# Downloading ETOPO: 106MB [00:15, 6.86MB/s]
# Downloading ETOPO: 106MB [00:15, 6.84MB/s]
# Downloading ETOPO: 107MB [00:15, 6.80MB/s]
# Downloading ETOPO: 108MB [00:15, 6.76MB/s]
# Downloading ETOPO: 108MB [00:15, 6.70MB/s]
# Downloading ETOPO: 109MB [00:16, 6.85MB/s]
# Downloading ETOPO: 110MB [00:16, 7.22MB/s]
# Downloading ETOPO: 111MB [00:16, 7.12MB/s]
# Downloading ETOPO: 111MB [00:16, 7.01MB/s]
# Downloading ETOPO: 112MB [00:16, 6.90MB/s]
# Downloading ETOPO: 113MB [00:16, 6.89MB/s]
# Downloading ETOPO: 113MB [00:16, 6.91MB/s]
# Downloading ETOPO: 114MB [00:16, 6.84MB/s]
# Downloading ETOPO: 115MB [00:16, 6.79MB/s]
# Downloading ETOPO: 115MB [00:16, 6.81MB/s]
# Downloading ETOPO: 116MB [00:17, 6.83MB/s]
# Downloading ETOPO: 117MB [00:17, 6.86MB/s]
# Downloading ETOPO: 117MB [00:17, 6.85MB/s]
# Downloading ETOPO: 118MB [00:17, 6.92MB/s]
# Downloading ETOPO: 119MB [00:17, 6.90MB/s]
# Downloading ETOPO: 120MB [00:17, 6.94MB/s]
# Downloading ETOPO: 120MB [00:17, 6.87MB/s]
# Downloading ETOPO: 121MB [00:17, 6.86MB/s]
# Downloading ETOPO: 122MB [00:17, 6.88MB/s]
# Downloading ETOPO: 122MB [00:18, 6.98MB/s]
# Downloading ETOPO: 123MB [00:18, 6.84MB/s]
# Downloading ETOPO: 124MB [00:18, 6.87MB/s]
# Downloading ETOPO: 124MB [00:18, 6.91MB/s]
# Downloading ETOPO: 125MB [00:18, 6.93MB/s]
# Downloading ETOPO: 126MB [00:18, 6.91MB/s]
# Downloading ETOPO: 127MB [00:18, 6.88MB/s]
# Downloading ETOPO: 127MB [00:18, 6.80MB/s]
# Downloading ETOPO: 128MB [00:18, 6.80MB/s]
# Downloading ETOPO: 129MB [00:19, 6.80MB/s]
# Downloading ETOPO: 129MB [00:19, 6.85MB/s]
# Downloading ETOPO: 130MB [00:19, 6.83MB/s]
# Downloading ETOPO: 131MB [00:19, 6.84MB/s]
# Downloading ETOPO: 131MB [00:19, 6.86MB/s]
# Downloading ETOPO: 132MB [00:19, 6.86MB/s]
# Downloading ETOPO: 133MB [00:19, 7.06MB/s]
# Downloading ETOPO: 133MB [00:19, 7.05MB/s]
# Downloading ETOPO: 134MB [00:19, 7.09MB/s]
# Downloading ETOPO: 135MB [00:19, 7.09MB/s]
# Downloading ETOPO: 136MB [00:20, 6.99MB/s]
# Downloading ETOPO: 136MB [00:20, 6.94MB/s]
# Downloading ETOPO: 137MB [00:20, 6.93MB/s]
# Downloading ETOPO: 138MB [00:20, 6.94MB/s]
# Downloading ETOPO: 138MB [00:20, 6.97MB/s]
# Downloading ETOPO: 139MB [00:20, 6.94MB/s]
# Downloading ETOPO: 140MB [00:20, 6.94MB/s]
# Downloading ETOPO: 141MB [00:20, 7.01MB/s]
# Downloading ETOPO: 141MB [00:20, 7.04MB/s]
# Downloading ETOPO: 142MB [00:21, 6.97MB/s]
# Downloading ETOPO: 143MB [00:21, 7.06MB/s]
# Downloading ETOPO: 143MB [00:21, 6.95MB/s]
# Downloading ETOPO: 144MB [00:21, 6.85MB/s]
# Downloading ETOPO: 145MB [00:21, 6.88MB/s]
# Downloading ETOPO: 145MB [00:21, 6.85MB/s]
# Downloading ETOPO: 146MB [00:21, 7.00MB/s]
# Downloading ETOPO: 147MB [00:21, 7.04MB/s]
# Downloading ETOPO: 148MB [00:21, 7.01MB/s]
# Downloading ETOPO: 148MB [00:21, 6.96MB/s]
# Downloading ETOPO: 149MB [00:22, 7.00MB/s]
# Downloading ETOPO: 150MB [00:22, 6.90MB/s]
# Downloading ETOPO: 150MB [00:22, 6.96MB/s]
# Downloading ETOPO: 151MB [00:22, 6.93MB/s]
# Downloading ETOPO: 152MB [00:22, 6.96MB/s]
# Downloading ETOPO: 189MB [00:28, 6.91MB/s]
# Downloading ETOPO: 190MB [00:28, 6.90MB/s]
# Downloading ETOPO: 190MB [00:28, 6.92MB/s]
# Downloading ETOPO: 191MB [00:28, 6.86MB/s]
# Downloading ETOPO: 192MB [00:28, 6.89MB/s]
# Downloading ETOPO: 193MB [00:28, 6.96MB/s]
# Downloading ETOPO: 193MB [00:28, 6.90MB/s]
# Downloading ETOPO: 194MB [00:28, 6.93MB/s]
# Downloading ETOPO: 195MB [00:28, 6.88MB/s]
# Downloading ETOPO: 195MB [00:29, 6.86MB/s]
# Downloading ETOPO: 196MB [00:29, 6.83MB/s]
# Downloading ETOPO: 197MB [00:29, 6.80MB/s]
# Downloading ETOPO: 197MB [00:29, 6.90MB/s]
# Downloading ETOPO: 198MB [00:29, 6.81MB/s]
# Downloading ETOPO: 199MB [00:29, 6.77MB/s]
# Downloading ETOPO: 199MB [00:29, 6.82MB/s]
# Downloading ETOPO: 200MB [00:29, 6.93MB/s]
# Downloading ETOPO: 201MB [00:29, 6.87MB/s]
# Downloading ETOPO: 202MB [00:30, 6.87MB/s]
# Downloading ETOPO: 202MB [00:30, 6.87MB/s]
# Downloading ETOPO: 203MB [00:30, 6.89MB/s]
# Downloading ETOPO: 204MB [00:30, 6.97MB/s]
# Downloading ETOPO: 204MB [00:30, 6.91MB/s]
# Downloading ETOPO: 205MB [00:30, 6.96MB/s]
# Downloading ETOPO: 206MB [00:30, 6.97MB/s]
# Downloading ETOPO: 206MB [00:30, 6.89MB/s]
# Downloading ETOPO: 207MB [00:30, 6.80MB/s]
# Downloading ETOPO: 208MB [00:30, 6.72MB/s]
# Downloading ETOPO: 208MB [00:31, 6.75MB/s]
# Downloading ETOPO: 209MB [00:31, 6.75MB/s]
# Downloading ETOPO: 210MB [00:31, 6.72MB/s]
# Downloading ETOPO: 210MB [00:31, 6.73MB/s]
# Downloading ETOPO: 211MB [00:31, 7.13MB/s]
# Downloading ETOPO: 212MB [00:31, 7.03MB/s]
# Downloading ETOPO: 213MB [00:31, 7.03MB/s]
# Downloading ETOPO: 213MB [00:31, 6.95MB/s]
# Downloading ETOPO: 214MB [00:31, 6.91MB/s]
# Downloading ETOPO: 215MB [00:32, 6.88MB/s]
# Downloading ETOPO: 215MB [00:32, 6.91MB/s]
# Downloading ETOPO: 216MB [00:32, 6.95MB/s]
# Downloading ETOPO: 217MB [00:32, 7.02MB/s]
# Downloading ETOPO: 218MB [00:32, 6.96MB/s]
# Downloading ETOPO: 218MB [00:32, 7.03MB/s]
# Downloading ETOPO: 219MB [00:32, 7.00MB/s]
# Downloading ETOPO: 220MB [00:32, 7.03MB/s]
# Downloading ETOPO: 220MB [00:32, 7.05MB/s]
# Downloading ETOPO: 221MB [00:33, 7.04MB/s]
# Downloading ETOPO: 222MB [00:33, 7.08MB/s]
# Downloading ETOPO: 223MB [00:33, 7.06MB/s]
# Downloading ETOPO: 223MB [00:33, 7.11MB/s]
# Downloading ETOPO: 224MB [00:33, 7.00MB/s]
# Downloading ETOPO: 225MB [00:33, 6.98MB/s]
# Downloading ETOPO: 225MB [00:33, 7.06MB/s]
# Downloading ETOPO: 226MB [00:33, 7.02MB/s]
# Downloading ETOPO: 227MB [00:33, 6.98MB/s]
# Downloading ETOPO: 228MB [00:33, 6.97MB/s]
# Downloading ETOPO: 228MB [00:34, 7.18MB/s]
# Downloading ETOPO: 229MB [00:34, 7.16MB/s]
# Downloading ETOPO: 230MB [00:34, 7.06MB/s]
# Downloading ETOPO: 230MB [00:34, 6.99MB/s]
# Downloading ETOPO: 231MB [00:34, 6.89MB/s]
# Downloading ETOPO: 232MB [00:34, 6.80MB/s]
# Downloading ETOPO: 232MB [00:34, 6.76MB/s]
# Downloading ETOPO: 233MB [00:34, 6.77MB/s]
# Downloading ETOPO: 234MB [00:34, 6.81MB/s]
# Downloading ETOPO: 235MB [00:35, 6.89MB/s]
# Downloading ETOPO: 235MB [00:35, 6.95MB/s]
# Downloading ETOPO: 236MB [00:35, 6.95MB/s]
# Downloading ETOPO: 237MB [00:35, 6.99MB/s]
# Downloading ETOPO: 237MB [00:35, 6.94MB/s]
# Downloading ETOPO: 238MB [00:35, 6.90MB/s]
# Downloading ETOPO: 239MB [00:35, 6.87MB/s]
# Downloading ETOPO: 239MB [00:35, 6.80MB/s]
# Downloading ETOPO: 240MB [00:35, 6.98MB/s]
# Downloading ETOPO: 241MB [00:35, 6.96MB/s]
# Downloading ETOPO: 242MB [00:36, 6.91MB/s]
# Downloading ETOPO: 242MB [00:36, 6.92MB/s]
# Downloading ETOPO: 243MB [00:36, 6.88MB/s]
# Downloading ETOPO: 244MB [00:36, 6.88MB/s]
# Downloading ETOPO: 244MB [00:36, 6.81MB/s]
# Downloading ETOPO: 245MB [00:36, 6.78MB/s]
# Downloading ETOPO: 246MB [00:36, 6.79MB/s]
# Downloading ETOPO: 246MB [00:36, 6.80MB/s]
# Downloading ETOPO: 247MB [00:36, 6.87MB/s]
# Downloading ETOPO: 248MB [00:37, 6.90MB/s]
# Downloading ETOPO: 249MB [00:37, 7.05MB/s]
# Downloading ETOPO: 249MB [00:37, 7.15MB/s]
# Downloading ETOPO: 250MB [00:37, 7.04MB/s]
# Downloading ETOPO: 251MB [00:37, 6.95MB/s]
# Downloading ETOPO: 251MB [00:37, 6.83MB/s]
# Downloading ETOPO: 252MB [00:37, 6.80MB/s]
# Downloading ETOPO: 253MB [00:37, 6.99MB/s]
# Downloading ETOPO: 253MB [00:37, 7.07MB/s]
# Downloading ETOPO: 254MB [00:37, 6.97MB/s]
# Downloading ETOPO: 255MB [00:38, 7.01MB/s]
# Downloading ETOPO: 256MB [00:38, 7.01MB/s]
# Downloading ETOPO: 256MB [00:38, 6.94MB/s]
# Downloading ETOPO: 257MB [00:38, 7.10MB/s]
# Downloading ETOPO: 258MB [00:38, 7.03MB/s]
# Downloading ETOPO: 258MB [00:38, 6.96MB/s]
# Downloading ETOPO: 259MB [00:38, 6.96MB/s]
# Downloading ETOPO: 260MB [00:38, 6.94MB/s]
# Downloading ETOPO: 260MB [00:38, 6.90MB/s]
# Downloading ETOPO: 261MB [00:39, 6.89MB/s]
# Downloading ETOPO: 262MB [00:39, 6.87MB/s]
# Downloading ETOPO: 263MB [00:39, 7.07MB/s]
# Downloading ETOPO: 263MB [00:39, 6.97MB/s]
# Downloading ETOPO: 264MB [00:39, 7.11MB/s]
# Downloading ETOPO: 265MB [00:39, 6.99MB/s]
# Downloading ETOPO: 265MB [00:39, 6.98MB/s]
# Downloading ETOPO: 266MB [00:39, 6.89MB/s]
# Downloading ETOPO: 267MB [00:39, 6.86MB/s]
# Downloading ETOPO: 268MB [00:40, 6.91MB/s]
# Downloading ETOPO: 268MB [00:40, 6.95MB/s]
# Downloading ETOPO: 269MB [00:40, 6.96MB/s]
# Downloading ETOPO: 270MB [00:40, 6.91MB/s]
# Downloading ETOPO: 270MB [00:40, 6.96MB/s]
# Downloading ETOPO: 271MB [00:40, 6.91MB/s]
# Downloading ETOPO: 272MB [00:40, 6.89MB/s]
# Downloading ETOPO: 272MB [00:40, 6.95MB/s]
# Downloading ETOPO: 273MB [00:40, 7.02MB/s]
# Downloading ETOPO: 274MB [00:40, 6.96MB/s]
# Downloading ETOPO: 275MB [00:41, 6.91MB/s]
# Downloading ETOPO: 275MB [00:41, 7.02MB/s]
# Downloading ETOPO: 276MB [00:41, 6.94MB/s]
# Downloading ETOPO: 277MB [00:41, 7.09MB/s]
# Downloading ETOPO: 277MB [00:41, 7.09MB/s]
# Downloading ETOPO: 278MB [00:41, 6.99MB/s]
# Downloading ETOPO: 279MB [00:41, 7.03MB/s]
# Downloading ETOPO: 280MB [00:41, 6.96MB/s]
# Downloading ETOPO: 280MB [00:41, 6.94MB/s]
# Downloading ETOPO: 281MB [00:42, 6.96MB/s]
# Downloading ETOPO: 282MB [00:42, 6.98MB/s]
# Downloading ETOPO: 282MB [00:42, 6.92MB/s]
# Downloading ETOPO: 283MB [00:42, 6.95MB/s]
# Downloading ETOPO: 284MB [00:42, 6.94MB/s]
# Downloading ETOPO: 284MB [00:42, 6.92MB/s]
# Downloading ETOPO: 285MB [00:42, 6.84MB/s]
# Downloading ETOPO: 286MB [00:42, 6.85MB/s]
# Downloading ETOPO: 287MB [00:42, 7.02MB/s]
# Downloading ETOPO: 287MB [00:42, 6.98MB/s]
# Downloading ETOPO: 288MB [00:43, 7.15MB/s]
# Downloading ETOPO: 289MB [00:43, 7.12MB/s]
# Downloading ETOPO: 289MB [00:43, 7.21MB/s]
# Downloading ETOPO: 290MB [00:43, 7.12MB/s]
# Downloading ETOPO: 291MB [00:43, 7.03MB/s]
# Downloading ETOPO: 292MB [00:43, 7.31MB/s]
# Downloading ETOPO: 292MB [00:43, 7.57MB/s]
# Downloading ETOPO: 293MB [00:43, 7.62MB/s]
# Downloading ETOPO: 294MB [00:43, 7.53MB/s]
# Downloading ETOPO: 295MB [00:44, 7.43MB/s]
# Downloading ETOPO: 295MB [00:44, 7.31MB/s]
# Downloading ETOPO: 296MB [00:44, 7.29MB/s]
# Downloading ETOPO: 297MB [00:44, 7.45MB/s]
# Downloading ETOPO: 298MB [00:44, 7.53MB/s]
# Downloading ETOPO: 299MB [00:44, 7.72MB/s]
# Downloading ETOPO: 299MB [00:44, 7.61MB/s]
# Downloading ETOPO: 300MB [00:44, 7.50MB/s]
# Downloading ETOPO: 301MB [00:44, 7.38MB/s]
# Downloading ETOPO: 302MB [00:44, 7.27MB/s]
# Downloading ETOPO: 302MB [00:45, 7.15MB/s]
# Downloading ETOPO: 303MB [00:45, 7.06MB/s]
# Downloading ETOPO: 304MB [00:45, 6.95MB/s]
# Downloading ETOPO: 304MB [00:45, 6.85MB/s]
# Downloading ETOPO: 305MB [00:45, 6.74MB/s]
# Downloading ETOPO: 306MB [00:45, 6.65MB/s]
# Downloading ETOPO: 306MB [00:45, 6.85MB/s]
# Downloading ETOPO: 307MB [00:45, 6.89MB/s]
# Downloading ETOPO: 308MB [00:45, 7.04MB/s]
# Downloading ETOPO: 308MB [00:46, 7.02MB/s]
# Downloading ETOPO: 309MB [00:46, 6.96MB/s]
# Downloading ETOPO: 310MB [00:46, 6.95MB/s]
# Downloading ETOPO: 311MB [00:46, 6.89MB/s]
# Downloading ETOPO: 311MB [00:46, 6.96MB/s]
# Downloading ETOPO: 312MB [00:46, 6.97MB/s]
# Downloading ETOPO: 313MB [00:46, 6.92MB/s]
# Downloading ETOPO: 313MB [00:46, 6.89MB/s]
# Downloading ETOPO: 314MB [00:46, 6.86MB/s]
# Downloading ETOPO: 315MB [00:47, 6.88MB/s]
# Downloading ETOPO: 315MB [00:47, 6.81MB/s]
# Downloading ETOPO: 316MB [00:47, 6.88MB/s]
# Downloading ETOPO: 317MB [00:47, 6.79MB/s]
# Downloading ETOPO: 317MB [00:47, 6.77MB/s]
# Downloading ETOPO: 318MB [00:47, 6.72MB/s]
# Downloading ETOPO: 319MB [00:47, 6.79MB/s]
# Downloading ETOPO: 319MB [00:47, 6.77MB/s]
# Downloading ETOPO: 320MB [00:47, 6.80MB/s]
# Downloading ETOPO: 321MB [00:47, 7.16MB/s]
# Downloading ETOPO: 322MB [00:48, 7.44MB/s]
# Downloading ETOPO: 323MB [00:48, 7.53MB/s]
# Downloading ETOPO: 323MB [00:48, 7.57MB/s]
# Downloading ETOPO: 324MB [00:48, 8.11MB/s]
# Downloading ETOPO: 325MB [00:48, 8.05MB/s]
# Downloading ETOPO: 326MB [00:48, 8.08MB/s]
# Downloading ETOPO: 327MB [00:48, 7.94MB/s]
# Downloading ETOPO: 328MB [00:48, 7.79MB/s]
# Downloading ETOPO: 328MB [00:48, 7.68MB/s]
# Downloading ETOPO: 329MB [00:49, 7.55MB/s]
# Downloading ETOPO: 330MB [00:49, 8.26MB/s]
# Downloading ETOPO: 331MB [00:49, 8.10MB/s]
# Downloading ETOPO: 332MB [00:49, 7.94MB/s]
# Downloading ETOPO: 332MB [00:49, 7.81MB/s]
# Downloading ETOPO: 333MB [00:49, 7.67MB/s]
# Downloading ETOPO: 334MB [00:49, 7.55MB/s]
# Downloading ETOPO: 335MB [00:49, 7.43MB/s]
# Downloading ETOPO: 446MB [01:06, 7.05MB/s]
# Downloading ETOPO: 447MB [01:06, 6.95MB/s]
# Downloading ETOPO: 447MB [01:06, 6.84MB/s]
# Downloading ETOPO: 448MB [01:06, 6.82MB/s]
# Downloading ETOPO: 449MB [01:06, 7.01MB/s]
# Downloading ETOPO: 450MB [01:06, 6.93MB/s]
# Downloading ETOPO: 450MB [01:06, 6.87MB/s]
# Downloading ETOPO: 451MB [01:07, 6.83MB/s]
# Downloading ETOPO: 452MB [01:07, 6.82MB/s]
# Downloading ETOPO: 452MB [01:07, 6.82MB/s]
# Downloading ETOPO: 453MB [01:07, 6.79MB/s]
# Downloading ETOPO: 454MB [01:07, 6.82MB/s]
# Downloading ETOPO: 454MB [01:07, 6.84MB/s]
# Downloading ETOPO: 455MB [01:07, 6.74MB/s]
# Downloading ETOPO: 456MB [01:07, 6.78MB/s]
# Downloading ETOPO: 456MB [01:07, 6.68MB/s]
# Downloading ETOPO: 457MB [01:08, 6.99MB/s]
# Downloading ETOPO: 458MB [01:08, 7.00MB/s]
# Downloading ETOPO: 459MB [01:08, 6.89MB/s]
# Downloading ETOPO: 459MB [01:08, 6.85MB/s]
# Downloading ETOPO: 460MB [01:08, 6.81MB/s]
# Downloading ETOPO: 461MB [01:08, 6.84MB/s]
# Downloading ETOPO: 461MB [01:08, 6.90MB/s]
# Downloading ETOPO: 462MB [01:08, 6.96MB/s]
# Downloading ETOPO: 463MB [01:08, 6.90MB/s]
# Downloading ETOPO: 463MB [01:08, 6.84MB/s]
# Downloading ETOPO: 464MB [01:09, 6.95MB/s]
# Downloading ETOPO: 465MB [01:09, 6.93MB/s]
# Downloading ETOPO: 466MB [01:09, 6.87MB/s]
# Downloading ETOPO: 466MB [01:09, 6.87MB/s]
# Downloading ETOPO: 467MB [01:09, 6.90MB/s]
# Downloading ETOPO: 468MB [01:09, 6.95MB/s]
# Downloading ETOPO: 468MB [01:09, 6.89MB/s]
# Downloading ETOPO: 469MB [01:09, 7.05MB/s]
# Download complete!

# %% [markdown]
# ### Step 2: Search PANGAEA Database
#
# **CLI Equivalent** (from root, rather than notebooks/ directory):
#
# ```bash
# cruiseplan pangaea "CTD" --lat 50 70 --lon -60 -30 --limit 5 --output-dir tests_output/demo --output demo`
# ```
#
# Search for relevant oceanographic datasets to inform our cruise planning.

# %%
print("🔍 Searching PANGAEA database and downloading station data...")

# Define search parameters
query = "CTD"  # or "CTD temperature North Atlantic"
lat_bounds = [50, 70]  # min_lat, max_lat
lon_bounds = [-60, -30]  # min_lon, max_lon
limit = 5

print(f"   Query: '{query}'")
print("   Geographic bounds: 50°N-70°N, 60°W-30°W")
print(f"   Limit: {limit} datasets")

# Search and download in one step
try:
    pangaea_result = cruiseplan.pangaea(
        query_terms=query,
        lat_bounds=lat_bounds,
        lon_bounds=lon_bounds,
        limit=limit,
        output_dir=str(output_dir),
        output="demo",
    )

    # Extract data from result
    pangaea_stations = pangaea_result.stations_data
    pangaea_files = pangaea_result.files_created

    if pangaea_files:
        print("✅ PANGAEA processing completed!")
        for file in pangaea_files:
            print(f"   📄 {file.name!s}")
    else:
        print("❌ No datasets found or processing failed")

except Exception as e:
    print(f"❌ PANGAEA processing failed: {e}")
# Out:
# 🔍 Searching PANGAEA database and downloading station data...
#    Query: 'CTD'
#    Geographic bounds: 50°N-70°N, 60°W-30°W
#    Limit: 5 datasets
# INFO: 🔍 Searching PANGAEA for: 'CTD'
# INFO: 📍 Geographic bounds: lat [50, 70], lon [-60, -30]
# INFO: Search found 1849 total matches. Retrieving first 5...
# INFO: ✅ Found 5 datasets
# INFO: 📂 DOI file: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_dois.txt
# INFO: 📂 Stations file: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo.pkl
# INFO: ⚙️ Processing 5 DOIs...
# INFO: 🕐 Rate limit: 1.0 requests/second
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.755512
# INFO: No events found for 10.1594/PANGAEA.755512, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604878
# INFO: No events found for 10.1594/PANGAEA.604878, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604842
# INFO: No events found for 10.1594/PANGAEA.604842, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604887
# /home/runner/micromamba/envs/cruiseplan/lib/python3.13/site-packages/pangaeapy/pandataset.py:1023: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.data["Event"] = list(self.events.values())[0].label
# INFO: No events found for 10.1594/PANGAEA.604887, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604857
# INFO: No events found for 10.1594/PANGAEA.604857, falling back to data table.
# INFO: ✅ PANGAEA processing completed successfully!
# INFO: 🚀 Next step: cruiseplan stations -p /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo.pkl
# ✅ PANGAEA processing completed!
#    📄 demo_dois.txt
#    📄 demo.pkl

# %% [markdown]
# ## Phase 2: Cruise configuration
#
# ### Step 3: Create Station Configuration
#
# **CLI Equivalent**:
# ```bash
# cruiseplan stations --pangaea-file demo_stations.pkl --lat 50 70 --lon -60 -30`
# ```
#
# **BUT** for this demo, we'll create a programmatic station configuration rather than using the interactive interface.  Maybe we'll make an interactive demo to show the other options, but the interactive part runs nicely from the command line.

# %%
print("🗺️  Creating station configuration...")

# Create a sample cruise configuration
cruise_config = {
    "cruise_name": "Demo North Atlantic Survey 2025",
    "default_vessel_speed": 10.0,
    "turnaround_time": 30.0,
    "ctd_descent_rate": 1.0,
    "ctd_ascent_rate": 1.0,
    "calculate_transfer_between_sections": True,
    "calculate_depth_via_bathymetry": True,
    "start_date": "2025-06-01T00:00:00Z",
    # Define stations along a transect
    "points": [
        {
            "name": "STN_001",
            "latitude": 55.0,
            "longitude": -50.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Continental shelf station",
        },
        {
            "name": "STN_002",
            "latitude": 57.0,
            "longitude": -45.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Slope station",
        },
        {
            "name": "STN_003",
            "latitude": 59.0,
            "longitude": -40.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Deep water station",
        },
        {
            "name": "STN_004",
            "latitude": 61.0,
            "longitude": -35.0,
            "operation_type": "water_sampling",
            "action": "sampling",
            "duration": 180.0,
            "comment": "Water sampling station",
        },
        {
            "name": "MOOR_001",
            "latitude": 60.5,
            "longitude": -38.0,
            "operation_type": "mooring",
            "action": "deployment",
            "duration": 240.0,
            "comment": "Mooring deployment",
        },
        {
            "name": "STN_005",
            "latitude": 63.0,
            "longitude": -30.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Northern end station",
        },
        {
            "name": "STN_006",
            "latitude": 58.0,
            "longitude": -42.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Return transect station",
        },
    ],
    # Add scientific transit
    "lines": [
        {
            "name": "Demo_ADCP_Survey",
            "operation_type": "underway",
            "action": "ADCP",
            "vessel_speed": 5.0,
            "route": [
                {"latitude": 56.0, "longitude": -48.0},
                {"latitude": 56.0, "longitude": -38.0},
            ],
            "comment": "Zonal ADCP survey transect",
        }
    ],
    # Define execution order with leg-based port definitions
    "legs": [
        {
            "name": "Demo_Survey",
            "departure_port": "port_st_johns",
            "arrival_port": "port_st_johns",
            "first_activity": "STN_001",
            "last_activity": "STN_006",
            "activities": [
                "STN_001",
                "STN_002",
                "STN_003",
                "Demo_ADCP_Survey",
                "STN_004",
                "MOOR_001",
                "STN_005",
                "STN_006",
            ],
        }
    ],
}

# Save configuration
config_file = output_dir / "demo_cruise.yaml"
save_yaml(cruise_config, config_file)

print("✅ Station configuration created")
print(f"   Configuration saved to: {config_file}")
print(f"   Waypoints: {len(cruise_config['points'])}")
print(f"   Transects: {len(cruise_config['lines'])}")
print(f"   Legs: {len(cruise_config['legs'])}")
# Out:
# INFO: Saved configuration to: ../tests_output/demo/demo_cruise.yaml
# 🗺️  Creating station configuration...
# ✅ Station configuration created
#    Configuration saved to: ../tests_output/demo/demo_cruise.yaml
#    Waypoints: 7
#    Transects: 1
#    Legs: 1

# %% [markdown]
# ### Step 3.5: Manually edit configuration
#
# The cruise configuration in `stations.yaml` will have some default values that need to be manually updated.  These include the `departure_port` and `arrival_port` within the cruise leg definition.  Default values are called "port_update", but can be replaced using values from the catalog of ports.
#
# ```yaml
# legs:
#   - name: Interactive_Survey
#     departure_port: port_update
#     arrival_port: port_update
#     first_waypoint: STN_001
#     last_waypoint: STN_002
#     strategy: sequential
#     activities:
#       - STN_001
#       - STN_002
#       - Transit_01
#       - Area_01
# ```

# %%
# Using cruiseplan.schema.ports with get_available_ports() and list_ports_in_region()

ports = get_available_ports()

# Display them nicely
for port_id, description in ports.items():
    print(f"{port_id}: {description}")

# Or get ports in a specific region
north_atlantic_ports = list_ports_in_region(
    min_lat=50.0, max_lat=70.0, min_lon=-30.0, max_lon=20.0
)

for port_id, port_name in north_atlantic_ports.items():
    print(f"{port_id}: {port_name}")

# If you want to add a custom port for your project
add_custom_port(
    "port_my_station",
    {
        "name": "My Research Station",
        "display_name": "My Research Station, Location",
        "latitude": 60.0,
        "longitude": -20.0,
        "timezone": "GMT+0",
        "description": "Custom research station for this cruise",
    },
)
# Out:
# port_reykjavik: Port: Reykjavik
# port_nuuk: Port: Nuuk
# port_tromso: Port: Tromsø
# port_trondheim: Port: Trondheim
# port_bergen: Port: Bergen
# port_southampton: Port: Southampton
# port_bremerhaven: Port: Bremerhaven
# port_hamburg: Port: Hamburg
# port_emden: Port: Emden
# port_rostock: Port: Rostock
# port_kiel: Port: Kiel
# port_brest: Port: Brest
# port_nice: Port: Nice
# port_vigo: Port: Vigo
# port_cadiz: Port: Cadiz
# port_malaga: Port: Malaga
# port_heraklion: Port: Heraklion
# port_catania: Port: Catania
# port_limassol: Port: Limassol
# port_las_palmas: Port: Las Palmas
# port_ponta_delgada: Port: Ponta Delgada
# port_funchal: Port: Funchal
# port_mindelo: Port: Mindelo
# port_walvis_bay: Port: Walvis Bay
# port_durban: Port: Durban
# port_halifax: Port: Halifax
# port_st_johns: Port: St. John's
# port_vancouver: Port: Vancouver
# port_woods_hole: Port: Woods Hole
# port_san_diego: Port: San Diego
# port_astoria: Port: Astoria
# port_honolulu: Port: Honolulu
# port_ensenada: Port: Ensenada
# port_balboa: Port: Balboa
# port_bridgetown: Port: Bridgetown
# port_rio_de_janeiro: Port: Rio de Janeiro
# port_fortaleza: Port: Fortaleza
# port_belem: Port: Belem
# port_recife: Port: Recife
# port_antofagasta: Port: Antofagasta
# port_port_louis_mauritius: Port: Port Louis
# port_la_reunion: Port: La Reunion
# port_port_louis_seychelles: Port: Port Louis
# port_colombo: Port: Colombo
# port_singapore: Port: Singapore
# port_yokohama: Port: Yokohama
# port_fremantle: Port: Fremantle
# port_wellington: Port: Wellington
# port_christchurch: Port: Christchurch
# port_auckland: Port: Auckland
# port_papeete: Port: Papeete
# port_update: Port: Hamburg (DEFAULT UPDATE PLACEHOLDER)
# port_update_departure: Port: Hamburg (DEPARTURE PLACEHOLDER)
# port_update_arrival: Port: Hamburg (ARRIVAL PLACEHOLDER)
# port_reykjavik: Reykjavik
# port_tromso: Tromsø
# port_trondheim: Trondheim
# port_bergen: Bergen
# port_southampton: Southampton
# port_bremerhaven: Bremerhaven
# port_hamburg: Hamburg
# port_emden: Emden
# port_rostock: Rostock
# port_kiel: Kiel
# port_update: Hamburg (DEFAULT UPDATE PLACEHOLDER)
# port_update_departure: Hamburg (DEPARTURE PLACEHOLDER)
# port_update_arrival: Hamburg (ARRIVAL PLACEHOLDER)

# %% [markdown]
# ### Step 4: Process Configuration
#
# **CLI Equivalent**: `cruiseplan enrich -c demo_cruise.yaml --add-depths --add-coords --expand-sections`
#
# Add computed data like depths, formatted coordinates, and expand CTD sections.

# %%
# Verify the function is available
print("Type of cruiseplan.process:", type(cruiseplan.process))
print("Is callable:", callable(cruiseplan.process))
print("🔧 Processing configuration (enrich + validate + map)...")
config_file = output_dir / "demo_cruise.yaml"

try:
    process_result = cruiseplan.process(
        config_file=config_file,
        output_dir=str(output_dir),
        output="demo_cruise",
        format="png",
        bathy_source="etopo2022",
        bathy_dir="../data/bathymetry",  # Go up to project root, then into data
        bathy_stride=10,
        figsize=[12, 8],
        depth_check=True,
        tolerance=10,
    )

    # Extract data from result
    cruise_config = process_result.config
    generated_config_files = process_result.files_created

    if cruise_config:
        print("✅ Processing completed successfully!")
        print("   - Configuration enriched")
        print("   - Validation passed")
        for file in generated_config_files:
            print(f"   📄 {file!s}")
    else:
        print("❌ Processing failed")

except Exception as e:
    print(f"❌ Processing failed: {e}")
    import traceback

    traceback.print_exc()
# Out:
# INFO: 🚀 Processing cruise configuration: ../tests_output/demo/demo_cruise.yaml
# INFO: 🔧 Enriching cruise configuration...
# INFO: 🔧 Enriching /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise.yaml
# INFO: Section expansion complete: 0 sections → 0 stations
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: Added depths to 7 stations using etopo2022
# INFO: Saved configuration to: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: ✅ Configuration enriched successfully: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: ✅ Validating cruise configuration...
# INFO: 🔍 Validating /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# Type of cruiseplan.process: <class 'function'>
# Is callable: True
# 🔧 Processing configuration (enrich + validate + map)...
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: ✅ Validation passed
# INFO: 🗺️ Generating cruise maps...
# INFO: Display bounds: 44.5°-66.1°N, -57.7°--25.0°E
# INFO: Loading bathymetry for region: 41.5°-69.1°N, -60.7°--22.0°E
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: Added bathymetry contours covering full region
# INFO: Map displayed with 8 points, 1 lines, 0 areas
# INFO: Map saved to /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_map.png
# INFO: ✅ Processing complete! Generated 2 files
# ✅ Processing completed successfully!
#    - Configuration enriched
#    - Validation passed
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_map.png

# %% [markdown]
# ## Phase 3: Cruise scheduling + outputs
#
# ### Step 5: Generate Schedule
#
# **CLI Equivalent**: `cruiseplan schedule -c demo_cruise_enriched.yaml -o tests_output/demo/ --format all`
#
# Generate the complete cruise timeline and output files.

# %%
# Find the enriched config file from the previous step
enriched_config_file = None
for files in generated_config_files:
    if str(files).endswith("enriched.yaml"):
        enriched_config_file = files
        break

if not enriched_config_file:
    enriched_config_file = output_dir / "demo_cruise_enriched.yaml"

print("📅 Generating cruise schedule...")

try:
    # Generate the schedule with multiple output formats using new API
    schedule_result = cruiseplan.schedule(
        config_file=enriched_config_file,
        output_dir="../tests_output/demo",
        output="demo_cruise",
        format="html,csv,netcdf",
        leg=None,
        derive_netcdf=True,
    )

    # Extract data from result
    timeline = schedule_result.timeline
    generated_files = schedule_result.files_created

    print("✅ Schedule generated successfully!")
    if timeline:
        print(f"   Timeline object created with {len(timeline)} activities")
        print("   Output files in: ../tests_output/demo/")
        print("   Generated formats: HTML, CSV, NetCDF")
        for file in generated_files:
            print(f"   - {file}")

    else:
        print("⚠️ No timeline generated")

except Exception as e:
    print(f"❌ Schedule generation failed: {e}")
    # Optionally show the full traceback for debugging
    import traceback

    traceback.print_exc()
# Out:
# INFO: 📅 Generating schedule from /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: 🌐 HTML Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
# INFO:    Timeline contains 19 activities
# INFO:    Adding to ports: St. John's (activity=Port, op_class=PointOperation, op_type=port)
# INFO:    Adding to stations: STN_001 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to stations: STN_002 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to stations: STN_003 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to scientific_transits: Demo_ADCP_Survey (activity=Line, op_class=LineOperation, op_type=underway)
# INFO:    Adding to stations (other): STN_004 (activity=Station, op_class=PointOperation, op_type=water_sampling)
# INFO:    Adding to moorings: MOOR_001 (activity=Mooring, op_class=PointOperation, op_type=mooring)
# INFO:    Adding to stations: STN_005 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to stations: STN_006 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to ports: St. John's (activity=Port, op_class=PointOperation, op_type=port)
# INFO: 🔍 Cruise-level operation counts:
# INFO:    Stations: 6
# INFO:    Moorings: 1
# INFO:    Scientific transits (surveys): 1
# INFO:    Area operations: 0
# INFO:    Total scientific operations: 8
# INFO:    Port activities: 2
# INFO:    Within-area transits: 7
# INFO: 🔍 Leg 'Demo_Survey' operation counts:
# INFO:    Stations: 5
# INFO:    Moorings: 1
# INFO:    Surveys: 1
# INFO:    Areas: 0
# INFO:    Total scientific operations: 8
# INFO:    Total activities in leg: 19
# INFO: ✅ Generated HTML schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
# INFO: 📊 CSV Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
# INFO:    Timeline contains 19 activities
# INFO: ✅ Generated CSV schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
# INFO: 📄 NetCDF Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO:    Timeline contains 19 activities
# INFO: ✅ Generated NetCDF schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO: 📅 Schedule generation complete! Generated 3 files
# 📅 Generating cruise schedule...
# ✅ Schedule generated successfully!
#    Timeline object created with 19 activities
#    Output files in: ../tests_output/demo/
#    Generated formats: HTML, CSV, NetCDF
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc

# %%
# Find the *.nc file in generated_files list of paths (from schedule result)
schedule_file = None
for file in generated_files:
    if str(file).endswith(".nc"):
        schedule_file = file
        break

if schedule_file:
    ds = xr.open_dataset(schedule_file)
    ds
else:
    print("No NetCDF file found in generated files")

# %%
ds
# Out:
# <xarray.Dataset> Size: 11kB
# Dimensions:           (obs: 19)
# Coordinates:
#     time              (obs) datetime64[ns] 152B ...
#     longitude         (obs) float32 76B ...
#     latitude          (obs) float32 76B ...
#     water_depth       (obs) float32 76B ...
# Dimensions without coordinates: obs
# Data variables: (12/20)
#     operation_depth   (obs) float32 76B ...
#     name              (obs) <U27 2kB ...
#     category          (obs) <U15 1kB ...
#     type              (obs) <U14 1kB ...
#     action            (obs) <U10 760B ...
#     comment           (obs) <U25 2kB ...
#     ...                ...
#     exit_latitude     (obs) float32 76B ...
#     exit_longitude    (obs) float32 76B ...
#     end_time          (obs) datetime64[ns] 152B ...
#     dist_nm           (obs) float32 76B ...
#     activity          (obs) <U7 532B ...
#     operation_class   (obs) <U19 1kB ...
# Attributes:
#     featureType:          trajectory
#     title:                Ship Schedule: Demo North Atlantic Survey 2025
#     institution:          Generated by CruisePlan software
#     source:               Scheduler computation from YAML configuration
#     Conventions:          CF-1.8
#     cruise_name:          Demo North Atlantic Survey 2025
#     total_duration_days:  16.279997299965277
#     creation_date:        2026-08-04T10:17:28
#     comment:              Master file containing all cruise data - specialize...

# %% [markdown]
# ## Workflow Summary
#
# Let's review what we've accomplished and check our output files.

# %%
all_files = pangaea_files + [config_file] + generated_config_files + generated_files

print("✅ CruisePlan Demo Complete!")
print(f"📁 Generated files: {len(all_files)} files in {Path(output_dir).name}/")
for file in all_files:
    print(f"   📄 {file.name}")
# Out:
# ✅ CruisePlan Demo Complete!
# 📁 Generated files: 8 files in demo/
#    📄 demo_dois.txt
#    📄 demo.pkl
#    📄 demo_cruise.yaml
#    📄 demo_cruise_enriched.yaml
#    📄 demo_cruise_map.png
#    📄 demo_cruise_schedule.html
#    📄 demo_cruise_schedule.csv
#    📄 demo_cruise_schedule.nc
