# %% [markdown]
# # CruisePlan Demo
#
# This notebook demonstrates the complete CruisePlan workflow using Python functions rather than CLI commands. Each section corresponds to a CLI subcommand and shows how to accomplish the same tasks programmatically.
#
# ## Workflow Overview
#
# The data preparation phase includes steps 1 and 2, the cruise configuration is steps 3 and 4, and the scheduling is step 5.
#
# 1. **Bathymetry**: Get bathymetry data for depth calculations
# 2. **Pangaea**: Search PANGAEA database for relevant oceanographic datasets
# 3. **Stations**: Interactive station planning (or programmatic configuration)
# 4. **Process**: Enrich configuration with depths/coordinates + validate
# 5. **Schedule**: Generate cruise timeline and outputs
#
# All outputs will be saved to `tests_output/demo/` for easy exploration.

# %% [markdown]
# ## Setup and Imports

# %%
# Core imports
import logging
from pathlib import Path

import xarray as xr

import cruiseplan
from cruiseplan.config.ports import (
    add_custom_port,
    get_available_ports,
    list_ports_in_region,
)
from cruiseplan.config.yaml_io import save_yaml

# Set up output directory
output_dir = Path("../tests_output/demo")
output_dir.mkdir(parents=True, exist_ok=True)

print(f"Demo outputs will be saved to: {output_dir.absolute()}")

# Configure logging to see what's happening
logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")
# Out:
# Demo outputs will be saved to: /home/runner/work/cruiseplan/cruiseplan/notebooks/../tests_output/demo

# %% [markdown]
# ## Phase 1: Data Preparation
#
# ### Step 1: Download Bathymetry Data
#
# **CLI Equivalent**:
#
# ```bash
# cruiseplan bathymetry --bathy-source etopo2022
# ```
#
# First, we need bathymetry data for depth calculations and visualization.

# %%
# Initialize bathymetry manager with ETOPO2022 data
print("📥 Downloading bathymetry data...")
bathy_result = cruiseplan.bathymetry(bathy_source="etopo2022")
bathy_path = bathy_result.data_file
# Out:
# INFO: 🌊 Downloading etopo2022 bathymetry data to /home/runner/work/cruiseplan/cruiseplan/data/bathymetry
# 📥 Downloading bathymetry data...
# Downloading ETOPO dataset to /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc...
# Attempting download from: https://www.ngdc.noaa.gov/thredds/fileServer/global/ETOPO2022/60s/60s_bed_elev_netcdf/ETOPO_2022_v1_60s_N90W180_bed.nc
# Downloading ETOPO: 0.00B [00:00, ?B/s]
# Downloading ETOPO: 48.0kB [00:00, 472kB/s]
# Downloading ETOPO: 200kB [00:00, 1.05MB/s]
# Downloading ETOPO: 424kB [00:00, 1.55MB/s]
# Downloading ETOPO: 703kB [00:00, 2.00MB/s]
# Downloading ETOPO: 1.11MB [00:00, 2.76MB/s]
# Downloading ETOPO: 1.55MB [00:00, 3.26MB/s]
# Downloading ETOPO: 2.01MB [00:00, 3.68MB/s]
# Downloading ETOPO: 2.48MB [00:00, 3.95MB/s]
# Downloading ETOPO: 2.97MB [00:00, 4.20MB/s]
# Downloading ETOPO: 3.46MB [00:01, 4.36MB/s]
# Downloading ETOPO: 3.96MB [00:01, 4.51MB/s]
# Downloading ETOPO: 4.45MB [00:01, 4.58MB/s]
# Downloading ETOPO: 4.92MB [00:01, 4.59MB/s]
# Downloading ETOPO: 5.39MB [00:01, 4.57MB/s]
# Downloading ETOPO: 5.83MB [00:01, 4.48MB/s]
# Downloading ETOPO: 6.30MB [00:01, 4.49MB/s]
# Downloading ETOPO: 6.81MB [00:01, 4.62MB/s]
# Downloading ETOPO: 7.30MB [00:01, 4.66MB/s]
# Downloading ETOPO: 7.79MB [00:02, 4.69MB/s]
# Downloading ETOPO: 8.26MB [00:02, 4.64MB/s]
# Downloading ETOPO: 8.76MB [00:02, 4.72MB/s]
# Downloading ETOPO: 9.26MB [00:02, 4.75MB/s]
# Downloading ETOPO: 9.72MB [00:02, 4.66MB/s]
# Downloading ETOPO: 10.2MB [00:02, 4.64MB/s]
# Downloading ETOPO: 10.7MB [00:02, 4.78MB/s]
# Downloading ETOPO: 11.2MB [00:02, 4.68MB/s]
# Downloading ETOPO: 11.6MB [00:02, 4.59MB/s]
# Downloading ETOPO: 12.1MB [00:03, 4.56MB/s]
# Downloading ETOPO: 12.6MB [00:03, 4.57MB/s]
# Downloading ETOPO: 13.1MB [00:03, 4.56MB/s]
# Downloading ETOPO: 13.5MB [00:03, 4.62MB/s]
# Downloading ETOPO: 14.1MB [00:03, 4.90MB/s]
# Downloading ETOPO: 14.6MB [00:03, 4.80MB/s]
# Downloading ETOPO: 15.1MB [00:03, 4.70MB/s]
# Downloading ETOPO: 15.5MB [00:03, 4.61MB/s]
# Downloading ETOPO: 16.0MB [00:03, 4.53MB/s]
# Downloading ETOPO: 16.4MB [00:04, 4.47MB/s]
# Downloading ETOPO: 17.0MB [00:04, 4.89MB/s]
# Downloading ETOPO: 17.5MB [00:04, 4.80MB/s]
# Downloading ETOPO: 18.0MB [00:04, 4.77MB/s]
# Downloading ETOPO: 18.5MB [00:04, 4.80MB/s]
# Downloading ETOPO: 19.0MB [00:04, 4.79MB/s]
# Downloading ETOPO: 19.5MB [00:04, 4.77MB/s]
# Downloading ETOPO: 20.0MB [00:04, 4.85MB/s]
# Downloading ETOPO: 20.4MB [00:04, 4.75MB/s]
# Downloading ETOPO: 20.9MB [00:04, 4.67MB/s]
# Downloading ETOPO: 21.4MB [00:05, 4.59MB/s]
# Downloading ETOPO: 21.8MB [00:05, 4.51MB/s]
# Downloading ETOPO: 22.2MB [00:05, 4.43MB/s]
# Downloading ETOPO: 22.7MB [00:05, 4.36MB/s]
# Downloading ETOPO: 23.1MB [00:05, 4.28MB/s]
# Downloading ETOPO: 23.5MB [00:05, 4.21MB/s]
# Downloading ETOPO: 23.9MB [00:05, 4.13MB/s]
# Downloading ETOPO: 24.3MB [00:05, 4.06MB/s]
# Downloading ETOPO: 24.7MB [00:05, 3.98MB/s]
# Downloading ETOPO: 25.2MB [00:06, 4.11MB/s]
# Downloading ETOPO: 25.7MB [00:06, 4.33MB/s]
# Downloading ETOPO: 26.2MB [00:06, 4.47MB/s]
# Downloading ETOPO: 26.6MB [00:06, 4.53MB/s]
# Downloading ETOPO: 27.1MB [00:06, 4.54MB/s]
# Downloading ETOPO: 27.6MB [00:06, 4.49MB/s]
# Downloading ETOPO: 28.1MB [00:06, 4.53MB/s]
# Downloading ETOPO: 28.5MB [00:06, 4.53MB/s]
# Downloading ETOPO: 29.0MB [00:06, 4.71MB/s]
# Downloading ETOPO: 29.5MB [00:07, 4.70MB/s]
# Downloading ETOPO: 30.1MB [00:07, 4.80MB/s]
# Downloading ETOPO: 30.5MB [00:07, 4.76MB/s]
# Downloading ETOPO: 31.0MB [00:07, 4.73MB/s]
# Downloading ETOPO: 31.5MB [00:07, 4.65MB/s]
# Downloading ETOPO: 32.0MB [00:07, 4.72MB/s]
# Downloading ETOPO: 32.4MB [00:07, 4.61MB/s]
# Downloading ETOPO: 33.0MB [00:07, 4.88MB/s]
# Downloading ETOPO: 33.6MB [00:07, 5.06MB/s]
# Downloading ETOPO: 34.1MB [00:08, 4.94MB/s]
# Downloading ETOPO: 34.6MB [00:08, 4.92MB/s]
# Downloading ETOPO: 35.1MB [00:08, 4.83MB/s]
# Downloading ETOPO: 35.6MB [00:08, 4.92MB/s]
# Downloading ETOPO: 36.1MB [00:08, 4.91MB/s]
# Downloading ETOPO: 36.6MB [00:08, 4.78MB/s]
# Downloading ETOPO: 37.0MB [00:08, 4.70MB/s]
# Downloading ETOPO: 37.5MB [00:08, 4.69MB/s]
# Downloading ETOPO: 38.0MB [00:08, 4.64MB/s]
# Downloading ETOPO: 38.4MB [00:08, 4.58MB/s]
# Downloading ETOPO: 38.9MB [00:09, 4.56MB/s]
# Downloading ETOPO: 39.4MB [00:09, 4.55MB/s]
# Downloading ETOPO: 39.9MB [00:09, 4.72MB/s]
# Downloading ETOPO: 40.4MB [00:09, 4.84MB/s]
# Downloading ETOPO: 40.9MB [00:09, 4.83MB/s]
# Downloading ETOPO: 41.4MB [00:09, 4.76MB/s]
# Downloading ETOPO: 41.9MB [00:09, 4.76MB/s]
# Downloading ETOPO: 42.4MB [00:09, 4.66MB/s]
# Downloading ETOPO: 42.8MB [00:09, 4.60MB/s]
# Downloading ETOPO: 43.3MB [00:10, 4.64MB/s]
# Downloading ETOPO: 43.8MB [00:10, 4.58MB/s]
# Downloading ETOPO: 44.3MB [00:10, 4.61MB/s]
# Downloading ETOPO: 44.8MB [00:10, 4.76MB/s]
# Downloading ETOPO: 45.3MB [00:10, 4.74MB/s]
# Downloading ETOPO: 45.7MB [00:10, 4.65MB/s]
# Downloading ETOPO: 46.2MB [00:10, 4.61MB/s]
# Downloading ETOPO: 46.7MB [00:10, 4.62MB/s]
# Downloading ETOPO: 47.2MB [00:10, 4.66MB/s]
# Downloading ETOPO: 47.7MB [00:11, 4.73MB/s]
# Downloading ETOPO: 48.1MB [00:11, 4.62MB/s]
# Downloading ETOPO: 48.6MB [00:11, 4.64MB/s]
# Downloading ETOPO: 49.1MB [00:11, 4.75MB/s]
# Downloading ETOPO: 49.6MB [00:11, 4.73MB/s]
# Downloading ETOPO: 50.1MB [00:11, 4.69MB/s]
# Downloading ETOPO: 50.6MB [00:11, 4.61MB/s]
# Downloading ETOPO: 51.2MB [00:11, 4.92MB/s]
# Downloading ETOPO: 51.6MB [00:11, 4.82MB/s]
# Downloading ETOPO: 52.1MB [00:12, 4.73MB/s]
# Downloading ETOPO: 52.6MB [00:12, 4.75MB/s]
# Downloading ETOPO: 53.1MB [00:12, 4.84MB/s]
# Downloading ETOPO: 53.7MB [00:12, 4.94MB/s]
# Downloading ETOPO: 54.1MB [00:12, 4.84MB/s]
# Downloading ETOPO: 54.6MB [00:12, 4.77MB/s]
# Downloading ETOPO: 55.1MB [00:12, 4.76MB/s]
# Downloading ETOPO: 55.6MB [00:12, 4.71MB/s]
# Downloading ETOPO: 56.1MB [00:12, 4.67MB/s]
# Downloading ETOPO: 56.6MB [00:13, 4.83MB/s]
# Downloading ETOPO: 57.1MB [00:13, 4.71MB/s]
# Downloading ETOPO: 57.6MB [00:13, 4.74MB/s]
# Downloading ETOPO: 58.0MB [00:13, 4.70MB/s]
# Downloading ETOPO: 58.5MB [00:13, 4.69MB/s]
# Downloading ETOPO: 59.0MB [00:13, 4.75MB/s]
# Downloading ETOPO: 59.5MB [00:13, 4.73MB/s]
# Downloading ETOPO: 60.0MB [00:13, 4.71MB/s]
# Downloading ETOPO: 60.5MB [00:13, 4.72MB/s]
# Downloading ETOPO: 61.0MB [00:13, 4.75MB/s]
# Downloading ETOPO: 61.5MB [00:14, 4.77MB/s]
# Downloading ETOPO: 61.9MB [00:14, 4.68MB/s]
# Downloading ETOPO: 62.4MB [00:14, 4.68MB/s]
# Downloading ETOPO: 62.9MB [00:14, 4.72MB/s]
# Downloading ETOPO: 63.4MB [00:14, 4.71MB/s]
# Downloading ETOPO: 63.9MB [00:14, 4.61MB/s]
# Downloading ETOPO: 64.3MB [00:14, 4.60MB/s]
# Downloading ETOPO: 64.8MB [00:14, 4.62MB/s]
# Downloading ETOPO: 65.3MB [00:14, 4.54MB/s]
# Downloading ETOPO: 65.8MB [00:15, 4.70MB/s]
# Downloading ETOPO: 66.3MB [00:15, 4.69MB/s]
# Downloading ETOPO: 66.7MB [00:15, 4.61MB/s]
# Downloading ETOPO: 67.2MB [00:15, 4.61MB/s]
# Downloading ETOPO: 67.7MB [00:15, 4.70MB/s]
# Downloading ETOPO: 68.2MB [00:15, 4.67MB/s]
# Downloading ETOPO: 68.7MB [00:15, 4.71MB/s]
# Downloading ETOPO: 69.2MB [00:15, 4.72MB/s]
# Downloading ETOPO: 69.7MB [00:15, 4.66MB/s]
# Downloading ETOPO: 70.2MB [00:16, 4.89MB/s]
# Downloading ETOPO: 70.7MB [00:16, 4.83MB/s]
# Downloading ETOPO: 71.2MB [00:16, 4.83MB/s]
# Downloading ETOPO: 71.7MB [00:16, 4.85MB/s]
# Downloading ETOPO: 72.2MB [00:16, 4.76MB/s]
# Downloading ETOPO: 72.6MB [00:16, 4.67MB/s]
# Downloading ETOPO: 73.1MB [00:16, 4.59MB/s]
# Downloading ETOPO: 73.5MB [00:16, 4.51MB/s]
# Downloading ETOPO: 74.0MB [00:16, 4.43MB/s]
# Downloading ETOPO: 74.4MB [00:17, 4.35MB/s]
# Downloading ETOPO: 74.8MB [00:17, 4.28MB/s]
# Downloading ETOPO: 75.2MB [00:17, 4.20MB/s]
# Downloading ETOPO: 75.6MB [00:17, 4.13MB/s]
# Downloading ETOPO: 76.1MB [00:17, 4.21MB/s]
# Downloading ETOPO: 76.6MB [00:17, 4.39MB/s]
# Downloading ETOPO: 77.1MB [00:17, 4.52MB/s]
# Downloading ETOPO: 77.6MB [00:17, 4.63MB/s]
# Downloading ETOPO: 78.0MB [00:17, 4.53MB/s]
# Downloading ETOPO: 78.6MB [00:18, 4.73MB/s]
# Downloading ETOPO: 79.0MB [00:18, 4.62MB/s]
# Downloading ETOPO: 79.5MB [00:18, 4.59MB/s]
# Downloading ETOPO: 80.0MB [00:18, 4.61MB/s]
# Downloading ETOPO: 80.5MB [00:18, 4.77MB/s]
# Downloading ETOPO: 81.1MB [00:18, 4.87MB/s]
# Downloading ETOPO: 81.5MB [00:18, 4.79MB/s]
# Downloading ETOPO: 82.0MB [00:18, 4.79MB/s]
# Downloading ETOPO: 82.5MB [00:18, 4.80MB/s]
# Downloading ETOPO: 83.1MB [00:18, 4.90MB/s]
# Downloading ETOPO: 83.6MB [00:19, 4.99MB/s]
# Downloading ETOPO: 84.1MB [00:19, 4.87MB/s]
# Downloading ETOPO: 84.5MB [00:19, 4.77MB/s]
# Downloading ETOPO: 85.0MB [00:19, 4.79MB/s]
# Downloading ETOPO: 85.5MB [00:19, 4.79MB/s]
# Downloading ETOPO: 86.0MB [00:19, 4.74MB/s]
# Downloading ETOPO: 86.5MB [00:19, 4.78MB/s]
# Downloading ETOPO: 87.0MB [00:19, 4.79MB/s]
# Downloading ETOPO: 87.5MB [00:19, 4.73MB/s]
# Downloading ETOPO: 88.0MB [00:20, 4.76MB/s]
# Downloading ETOPO: 88.5MB [00:20, 4.84MB/s]
# Downloading ETOPO: 89.0MB [00:20, 4.81MB/s]
# Downloading ETOPO: 89.5MB [00:20, 4.72MB/s]
# Downloading ETOPO: 90.0MB [00:20, 4.75MB/s]
# Downloading ETOPO: 90.5MB [00:20, 4.70MB/s]
# Downloading ETOPO: 90.9MB [00:20, 4.64MB/s]
# Downloading ETOPO: 91.4MB [00:20, 4.56MB/s]
# Downloading ETOPO: 91.8MB [00:20, 4.52MB/s]
# Downloading ETOPO: 92.3MB [00:21, 4.52MB/s]
# Downloading ETOPO: 92.8MB [00:21, 4.53MB/s]
# Downloading ETOPO: 93.3MB [00:21, 4.69MB/s]
# Downloading ETOPO: 93.8MB [00:21, 4.64MB/s]
# Downloading ETOPO: 94.3MB [00:21, 4.71MB/s]
# Downloading ETOPO: 94.8MB [00:21, 4.70MB/s]
# Downloading ETOPO: 95.3MB [00:21, 4.78MB/s]
# Downloading ETOPO: 95.8MB [00:21, 4.75MB/s]
# Downloading ETOPO: 96.3MB [00:21, 4.77MB/s]
# Downloading ETOPO: 96.7MB [00:22, 4.67MB/s]
# Downloading ETOPO: 97.2MB [00:22, 4.76MB/s]
# Downloading ETOPO: 97.7MB [00:22, 4.67MB/s]
# Downloading ETOPO: 98.2MB [00:22, 4.67MB/s]
# Downloading ETOPO: 98.6MB [00:22, 4.60MB/s]
# Downloading ETOPO: 99.1MB [00:22, 4.55MB/s]
# Downloading ETOPO: 99.6MB [00:22, 4.57MB/s]
# Downloading ETOPO: 100MB [00:22, 4.62MB/s]
# Downloading ETOPO: 101MB [00:22, 4.66MB/s]
# Downloading ETOPO: 101MB [00:23, 4.68MB/s]
# Downloading ETOPO: 102MB [00:23, 4.70MB/s]
# Downloading ETOPO: 102MB [00:23, 4.69MB/s]
# Downloading ETOPO: 103MB [00:23, 4.71MB/s]
# Downloading ETOPO: 103MB [00:23, 4.65MB/s]
# Downloading ETOPO: 103MB [00:23, 4.68MB/s]
# Downloading ETOPO: 104MB [00:23, 4.68MB/s]
# Downloading ETOPO: 104MB [00:23, 4.77MB/s]
# Downloading ETOPO: 105MB [00:23, 4.68MB/s]
# Downloading ETOPO: 105MB [00:23, 4.60MB/s]
# Downloading ETOPO: 106MB [00:24, 4.51MB/s]
# Downloading ETOPO: 106MB [00:24, 4.43MB/s]
# Downloading ETOPO: 107MB [00:24, 4.57MB/s]
# Downloading ETOPO: 107MB [00:24, 4.65MB/s]
# Downloading ETOPO: 108MB [00:24, 4.59MB/s]
# Downloading ETOPO: 108MB [00:24, 4.65MB/s]
# Downloading ETOPO: 109MB [00:24, 4.81MB/s]
# Downloading ETOPO: 109MB [00:24, 4.70MB/s]
# Downloading ETOPO: 110MB [00:24, 4.83MB/s]
# Downloading ETOPO: 110MB [00:25, 4.71MB/s]
# Downloading ETOPO: 111MB [00:25, 4.61MB/s]
# Downloading ETOPO: 111MB [00:25, 4.63MB/s]
# Downloading ETOPO: 112MB [00:25, 4.57MB/s]
# Downloading ETOPO: 112MB [00:25, 4.85MB/s]
# Downloading ETOPO: 113MB [00:25, 4.90MB/s]
# Downloading ETOPO: 113MB [00:25, 4.86MB/s]
# Downloading ETOPO: 114MB [00:25, 4.91MB/s]
# Downloading ETOPO: 114MB [00:25, 4.84MB/s]
# Downloading ETOPO: 115MB [00:26, 4.92MB/s]
# Downloading ETOPO: 115MB [00:26, 4.82MB/s]
# Downloading ETOPO: 116MB [00:26, 4.72MB/s]
# Downloading ETOPO: 116MB [00:26, 4.66MB/s]
# Downloading ETOPO: 117MB [00:26, 4.64MB/s]
# Downloading ETOPO: 117MB [00:26, 4.62MB/s]
# Downloading ETOPO: 118MB [00:26, 4.68MB/s]
# Downloading ETOPO: 118MB [00:26, 4.72MB/s]
# Downloading ETOPO: 119MB [00:26, 4.62MB/s]
# Downloading ETOPO: 119MB [00:27, 4.63MB/s]
# Downloading ETOPO: 120MB [00:27, 4.62MB/s]
# Downloading ETOPO: 120MB [00:27, 4.59MB/s]
# Downloading ETOPO: 120MB [00:27, 4.61MB/s]
# Downloading ETOPO: 121MB [00:27, 4.52MB/s]
# Downloading ETOPO: 121MB [00:27, 4.45MB/s]
# Downloading ETOPO: 122MB [00:27, 4.63MB/s]
# Downloading ETOPO: 122MB [00:27, 4.62MB/s]
# Downloading ETOPO: 123MB [00:27, 4.59MB/s]
# Downloading ETOPO: 123MB [00:28, 4.68MB/s]
# Downloading ETOPO: 124MB [00:28, 4.58MB/s]
# Downloading ETOPO: 124MB [00:28, 4.63MB/s]
# Downloading ETOPO: 125MB [00:28, 4.88MB/s]
# Downloading ETOPO: 125MB [00:28, 4.80MB/s]
# Downloading ETOPO: 126MB [00:28, 4.81MB/s]
# Downloading ETOPO: 126MB [00:28, 4.93MB/s]
# Downloading ETOPO: 127MB [00:28, 4.85MB/s]
# Downloading ETOPO: 127MB [00:28, 4.80MB/s]
# Downloading ETOPO: 128MB [00:28, 4.83MB/s]
# Downloading ETOPO: 128MB [00:29, 4.87MB/s]
# Downloading ETOPO: 129MB [00:29, 4.83MB/s]
# Downloading ETOPO: 129MB [00:29, 4.74MB/s]
# Downloading ETOPO: 130MB [00:29, 4.78MB/s]
# Downloading ETOPO: 130MB [00:29, 4.77MB/s]
# Downloading ETOPO: 131MB [00:29, 4.72MB/s]
# Downloading ETOPO: 131MB [00:29, 4.84MB/s]
# Downloading ETOPO: 132MB [00:29, 4.81MB/s]
# Downloading ETOPO: 132MB [00:29, 4.75MB/s]
# Downloading ETOPO: 133MB [00:30, 4.77MB/s]
# Downloading ETOPO: 133MB [00:30, 4.92MB/s]
# Downloading ETOPO: 134MB [00:30, 4.83MB/s]
# Downloading ETOPO: 134MB [00:30, 4.85MB/s]
# Downloading ETOPO: 135MB [00:30, 4.80MB/s]
# Downloading ETOPO: 135MB [00:30, 4.85MB/s]
# Downloading ETOPO: 136MB [00:30, 4.79MB/s]
# Downloading ETOPO: 136MB [00:30, 4.82MB/s]
# Downloading ETOPO: 137MB [00:30, 4.93MB/s]
# Downloading ETOPO: 137MB [00:31, 4.83MB/s]
# Downloading ETOPO: 138MB [00:31, 4.71MB/s]
# Downloading ETOPO: 138MB [00:31, 4.60MB/s]
# Downloading ETOPO: 139MB [00:31, 4.51MB/s]
# Downloading ETOPO: 139MB [00:31, 4.49MB/s]
# Downloading ETOPO: 140MB [00:31, 4.52MB/s]
# Downloading ETOPO: 140MB [00:31, 4.55MB/s]
# Downloading ETOPO: 141MB [00:31, 4.58MB/s]
# Downloading ETOPO: 141MB [00:31, 4.61MB/s]
# Downloading ETOPO: 142MB [00:32, 4.63MB/s]
# Downloading ETOPO: 142MB [00:32, 4.66MB/s]
# Downloading ETOPO: 143MB [00:32, 4.76MB/s]
# Downloading ETOPO: 143MB [00:32, 4.69MB/s]
# Downloading ETOPO: 144MB [00:32, 4.66MB/s]
# Downloading ETOPO: 144MB [00:32, 4.77MB/s]
# Downloading ETOPO: 145MB [00:32, 4.76MB/s]
# Downloading ETOPO: 145MB [00:32, 4.73MB/s]
# Downloading ETOPO: 145MB [00:32, 4.69MB/s]
# Downloading ETOPO: 146MB [00:33, 4.72MB/s]
# Downloading ETOPO: 147MB [00:33, 4.84MB/s]
# Downloading ETOPO: 147MB [00:33, 4.81MB/s]
# Downloading ETOPO: 147MB [00:33, 4.77MB/s]
# Downloading ETOPO: 148MB [00:33, 4.67MB/s]
# Downloading ETOPO: 148MB [00:33, 4.63MB/s]
# Downloading ETOPO: 149MB [00:33, 4.59MB/s]
# Downloading ETOPO: 149MB [00:33, 4.59MB/s]
# Downloading ETOPO: 150MB [00:33, 4.74MB/s]
# Downloading ETOPO: 150MB [00:33, 4.70MB/s]
# Downloading ETOPO: 151MB [00:34, 4.76MB/s]
# Downloading ETOPO: 151MB [00:34, 4.73MB/s]
# Downloading ETOPO: 152MB [00:34, 4.73MB/s]
# Downloading ETOPO: 152MB [00:34, 4.71MB/s]
# Downloading ETOPO: 153MB [00:34, 4.77MB/s]
# Downloading ETOPO: 153MB [00:34, 4.76MB/s]
# Downloading ETOPO: 154MB [00:34, 4.79MB/s]
# Downloading ETOPO: 154MB [00:34, 4.77MB/s]
# Downloading ETOPO: 155MB [00:34, 4.77MB/s]
# Downloading ETOPO: 155MB [00:35, 4.76MB/s]
# Downloading ETOPO: 156MB [00:35, 4.84MB/s]
# Downloading ETOPO: 156MB [00:35, 4.75MB/s]
# Downloading ETOPO: 157MB [00:35, 4.73MB/s]
# Downloading ETOPO: 157MB [00:35, 4.71MB/s]
# Downloading ETOPO: 158MB [00:35, 4.74MB/s]
# Downloading ETOPO: 158MB [00:35, 4.72MB/s]
# Downloading ETOPO: 159MB [00:35, 4.73MB/s]
# Downloading ETOPO: 159MB [00:35, 4.67MB/s]
# Downloading ETOPO: 160MB [00:36, 4.60MB/s]
# Downloading ETOPO: 160MB [00:36, 4.67MB/s]
# Downloading ETOPO: 161MB [00:36, 4.60MB/s]
# Downloading ETOPO: 161MB [00:36, 4.60MB/s]
# Downloading ETOPO: 162MB [00:36, 4.69MB/s]
# Downloading ETOPO: 162MB [00:36, 4.70MB/s]
# Downloading ETOPO: 163MB [00:36, 4.72MB/s]
# Downloading ETOPO: 163MB [00:36, 4.63MB/s]
# Downloading ETOPO: 164MB [00:36, 4.85MB/s]
# Downloading ETOPO: 164MB [00:37, 4.81MB/s]
# Downloading ETOPO: 165MB [00:37, 4.79MB/s]
# Downloading ETOPO: 165MB [00:37, 4.75MB/s]
# Downloading ETOPO: 166MB [00:37, 4.82MB/s]
# Downloading ETOPO: 166MB [00:37, 4.80MB/s]
# Downloading ETOPO: 167MB [00:37, 4.74MB/s]
# Downloading ETOPO: 167MB [00:37, 4.78MB/s]
# Downloading ETOPO: 168MB [00:37, 4.70MB/s]
# Downloading ETOPO: 168MB [00:37, 4.74MB/s]
# Downloading ETOPO: 169MB [00:38, 5.05MB/s]
# Downloading ETOPO: 169MB [00:38, 5.00MB/s]
# Downloading ETOPO: 170MB [00:38, 4.90MB/s]
# Downloading ETOPO: 170MB [00:38, 4.79MB/s]
# Downloading ETOPO: 171MB [00:38, 4.70MB/s]
# Downloading ETOPO: 171MB [00:38, 4.61MB/s]
# Downloading ETOPO: 171MB [00:38, 4.51MB/s]
# Downloading ETOPO: 172MB [00:38, 4.60MB/s]
# Downloading ETOPO: 172MB [00:38, 4.56MB/s]
# Downloading ETOPO: 173MB [00:38, 4.54MB/s]
# Downloading ETOPO: 173MB [00:39, 4.62MB/s]
# Downloading ETOPO: 174MB [00:39, 4.75MB/s]
# Downloading ETOPO: 174MB [00:39, 4.83MB/s]
# Downloading ETOPO: 175MB [00:39, 4.74MB/s]
# Downloading ETOPO: 175MB [00:39, 4.79MB/s]
# Downloading ETOPO: 176MB [00:39, 4.75MB/s]
# Downloading ETOPO: 176MB [00:39, 4.66MB/s]
# Downloading ETOPO: 177MB [00:39, 4.73MB/s]
# Downloading ETOPO: 177MB [00:39, 4.84MB/s]
# Downloading ETOPO: 178MB [00:40, 4.86MB/s]
# Downloading ETOPO: 178MB [00:40, 4.75MB/s]
# Downloading ETOPO: 179MB [00:40, 4.66MB/s]
# Downloading ETOPO: 179MB [00:40, 4.62MB/s]
# Downloading ETOPO: 180MB [00:40, 4.59MB/s]
# Downloading ETOPO: 180MB [00:40, 4.59MB/s]
# Downloading ETOPO: 181MB [00:40, 4.61MB/s]
# Downloading ETOPO: 181MB [00:40, 4.60MB/s]
# Downloading ETOPO: 182MB [00:40, 4.55MB/s]
# Downloading ETOPO: 182MB [00:41, 4.74MB/s]
# Downloading ETOPO: 183MB [00:41, 4.63MB/s]
# Downloading ETOPO: 183MB [00:41, 4.69MB/s]
# Downloading ETOPO: 184MB [00:41, 4.59MB/s]
# Downloading ETOPO: 184MB [00:41, 4.70MB/s]
# Downloading ETOPO: 185MB [00:41, 4.64MB/s]
# Downloading ETOPO: 185MB [00:41, 4.65MB/s]
# Downloading ETOPO: 186MB [00:41, 4.63MB/s]
# Downloading ETOPO: 186MB [00:41, 4.59MB/s]
# Downloading ETOPO: 186MB [00:42, 4.56MB/s]
# Downloading ETOPO: 187MB [00:42, 4.49MB/s]
# Downloading ETOPO: 187MB [00:42, 4.68MB/s]
# Downloading ETOPO: 188MB [00:42, 4.72MB/s]
# Downloading ETOPO: 188MB [00:42, 4.70MB/s]
# Downloading ETOPO: 189MB [00:42, 4.74MB/s]
# Downloading ETOPO: 189MB [00:42, 4.67MB/s]
# Downloading ETOPO: 190MB [00:42, 4.60MB/s]
# Downloading ETOPO: 190MB [00:42, 4.60MB/s]
# Downloading ETOPO: 191MB [00:43, 4.67MB/s]
# Downloading ETOPO: 191MB [00:43, 4.62MB/s]
# Downloading ETOPO: 192MB [00:43, 4.61MB/s]
# Downloading ETOPO: 192MB [00:43, 4.65MB/s]
# Downloading ETOPO: 193MB [00:43, 4.59MB/s]
# Downloading ETOPO: 193MB [00:43, 4.63MB/s]
# Downloading ETOPO: 194MB [00:43, 4.64MB/s]
# Downloading ETOPO: 194MB [00:43, 4.67MB/s]
# Downloading ETOPO: 195MB [00:43, 4.67MB/s]
# Downloading ETOPO: 195MB [00:43, 4.70MB/s]
# Downloading ETOPO: 196MB [00:44, 4.69MB/s]
# Downloading ETOPO: 196MB [00:44, 4.62MB/s]
# Downloading ETOPO: 197MB [00:44, 4.57MB/s]
# Downloading ETOPO: 197MB [00:44, 4.60MB/s]
# Downloading ETOPO: 198MB [00:44, 4.66MB/s]
# Downloading ETOPO: 198MB [00:44, 4.64MB/s]
# Downloading ETOPO: 199MB [00:44, 4.67MB/s]
# Downloading ETOPO: 199MB [00:44, 4.81MB/s]
# Downloading ETOPO: 200MB [00:44, 4.77MB/s]
# Downloading ETOPO: 200MB [00:45, 4.71MB/s]
# Downloading ETOPO: 451MB [01:41, 4.88MB/s]
# Downloading ETOPO: 452MB [01:41, 4.79MB/s]
# Downloading ETOPO: 452MB [01:41, 4.74MB/s]
# Downloading ETOPO: 453MB [01:41, 4.65MB/s]
# Downloading ETOPO: 453MB [01:41, 4.66MB/s]
# Downloading ETOPO: 454MB [01:41, 4.84MB/s]
# Downloading ETOPO: 454MB [01:41, 4.81MB/s]
# Downloading ETOPO: 455MB [01:41, 4.91MB/s]
# Downloading ETOPO: 455MB [01:41, 4.79MB/s]
# Downloading ETOPO: 456MB [01:42, 4.73MB/s]
# Downloading ETOPO: 456MB [01:42, 4.72MB/s]
# Downloading ETOPO: 457MB [01:42, 4.72MB/s]
# Downloading ETOPO: 457MB [01:42, 4.75MB/s]
# Downloading ETOPO: 458MB [01:42, 4.75MB/s]
# Downloading ETOPO: 458MB [01:42, 4.73MB/s]
# Downloading ETOPO: 459MB [01:42, 4.69MB/s]
# Downloading ETOPO: 459MB [01:42, 4.70MB/s]
# Downloading ETOPO: 460MB [01:42, 4.65MB/s]
# Downloading ETOPO: 460MB [01:43, 4.68MB/s]
# Downloading ETOPO: 461MB [01:43, 4.65MB/s]
# Downloading ETOPO: 461MB [01:43, 4.66MB/s]
# Downloading ETOPO: 461MB [01:43, 4.59MB/s]
# Downloading ETOPO: 462MB [01:43, 4.62MB/s]
# Downloading ETOPO: 462MB [01:43, 4.59MB/s]
# Downloading ETOPO: 463MB [01:43, 4.77MB/s]
# Downloading ETOPO: 463MB [01:43, 4.76MB/s]
# Downloading ETOPO: 464MB [01:43, 4.71MB/s]
# Downloading ETOPO: 464MB [01:44, 4.63MB/s]
# Downloading ETOPO: 465MB [01:44, 4.82MB/s]
# Downloading ETOPO: 465MB [01:44, 4.71MB/s]
# Downloading ETOPO: 466MB [01:44, 4.63MB/s]
# Downloading ETOPO: 466MB [01:44, 4.67MB/s]
# Downloading ETOPO: 467MB [01:44, 4.71MB/s]
# Downloading ETOPO: 467MB [01:44, 4.84MB/s]
# Downloading ETOPO: 468MB [01:44, 4.85MB/s]
# Downloading ETOPO: 468MB [01:44, 4.76MB/s]
# Downloading ETOPO: 469MB [01:44, 4.68MB/s]
# Download complete!

# %% [markdown]
# ### Step 2: Search PANGAEA Database
#
# **CLI Equivalent** (from root, rather than notebooks/ directory):
#
# ```bash
# cruiseplan pangaea "CTD" --lat 50 70 --lon -60 -30 --limit 5 --output-dir tests_output/demo --output demo`
# ```
#
# Search for relevant oceanographic datasets to inform our cruise planning.

# %%
print("🔍 Searching PANGAEA database and downloading station data...")

# Define search parameters
query = "CTD"  # or "CTD temperature North Atlantic"
lat_bounds = [50, 70]  # min_lat, max_lat
lon_bounds = [-60, -30]  # min_lon, max_lon
limit = 5

print(f"   Query: '{query}'")
print("   Geographic bounds: 50°N-70°N, 60°W-30°W")
print(f"   Limit: {limit} datasets")

# Search and download in one step
try:
    pangaea_result = cruiseplan.pangaea(
        query_terms=query,
        lat_bounds=lat_bounds,
        lon_bounds=lon_bounds,
        limit=limit,
        output_dir=str(output_dir),
        output="demo",
    )

    # Extract data from result
    pangaea_stations = pangaea_result.stations_data
    pangaea_files = pangaea_result.files_created

    if pangaea_files:
        print("✅ PANGAEA processing completed!")
        for file in pangaea_files:
            print(f"   📄 {file.name!s}")
    else:
        print("❌ No datasets found or processing failed")

except Exception as e:
    print(f"❌ PANGAEA processing failed: {e}")
# Out:
# 🔍 Searching PANGAEA database and downloading station data...
#    Query: 'CTD'
#    Geographic bounds: 50°N-70°N, 60°W-30°W
#    Limit: 5 datasets
# INFO: 🔍 Searching PANGAEA for: 'CTD'
# INFO: 📍 Geographic bounds: lat [50, 70], lon [-60, -30]
# INFO: Search found 1849 total matches. Retrieving first 5...
# INFO: ✅ Found 5 datasets
# INFO: 📂 DOI file: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_dois.txt
# INFO: 📂 Stations file: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo.pkl
# INFO: ⚙️ Processing 5 DOIs...
# INFO: 🕐 Rate limit: 1.0 requests/second
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.755512
# INFO: No events found for 10.1594/PANGAEA.755512, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604878
# INFO: No events found for 10.1594/PANGAEA.604878, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604842
# INFO: No events found for 10.1594/PANGAEA.604842, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604887
# /home/runner/micromamba/envs/cruiseplan/lib/python3.13/site-packages/pangaeapy/pandataset.py:1023: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.data["Event"] = list(self.events.values())[0].label
# INFO: No events found for 10.1594/PANGAEA.604887, falling back to data table.
# INFO: Fetching PANGAEA dataset: 10.1594/PANGAEA.604857
# INFO: No events found for 10.1594/PANGAEA.604857, falling back to data table.
# INFO: ✅ PANGAEA processing completed successfully!
# INFO: 🚀 Next step: cruiseplan stations -p /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo.pkl
# ✅ PANGAEA processing completed!
#    📄 demo_dois.txt
#    📄 demo.pkl

# %% [markdown]
# ## Phase 2: Cruise configuration
#
# ### Step 3: Create Station Configuration
#
# **CLI Equivalent**:
# ```bash
# cruiseplan stations --pangaea-file demo_stations.pkl --lat 50 70 --lon -60 -30`
# ```
#
# **BUT** for this demo, we'll create a programmatic station configuration rather than using the interactive interface.  Maybe we'll make an interactive demo to show the other options, but the interactive part runs nicely from the command line.

# %%
print("🗺️  Creating station configuration...")

# Create a sample cruise configuration
cruise_config = {
    "cruise_name": "Demo North Atlantic Survey 2025",
    "default_vessel_speed": 10.0,
    "turnaround_time": 30.0,
    "ctd_descent_rate": 1.0,
    "ctd_ascent_rate": 1.0,
    "calculate_transfer_between_sections": True,
    "calculate_depth_via_bathymetry": True,
    "start_date": "2025-06-01T00:00:00Z",
    # Define stations along a transect
    "points": [
        {
            "name": "STN_001",
            "latitude": 55.0,
            "longitude": -50.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Continental shelf station",
        },
        {
            "name": "STN_002",
            "latitude": 57.0,
            "longitude": -45.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Slope station",
        },
        {
            "name": "STN_003",
            "latitude": 59.0,
            "longitude": -40.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Deep water station",
        },
        {
            "name": "STN_004",
            "latitude": 61.0,
            "longitude": -35.0,
            "operation_type": "water_sampling",
            "action": "sampling",
            "duration": 180.0,
            "comment": "Water sampling station",
        },
        {
            "name": "MOOR_001",
            "latitude": 60.5,
            "longitude": -38.0,
            "operation_type": "mooring",
            "action": "deployment",
            "duration": 240.0,
            "comment": "Mooring deployment",
        },
        {
            "name": "STN_005",
            "latitude": 63.0,
            "longitude": -30.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Northern end station",
        },
        {
            "name": "STN_006",
            "latitude": 58.0,
            "longitude": -42.0,
            "operation_type": "CTD",
            "action": "profile",
            "comment": "Return transect station",
        },
    ],
    # Add scientific transit
    "lines": [
        {
            "name": "Demo_ADCP_Survey",
            "operation_type": "underway",
            "action": "ADCP",
            "vessel_speed": 5.0,
            "route": [
                {"latitude": 56.0, "longitude": -48.0},
                {"latitude": 56.0, "longitude": -38.0},
            ],
            "comment": "Zonal ADCP survey transect",
        }
    ],
    # Define execution order with leg-based port definitions
    "legs": [
        {
            "name": "Demo_Survey",
            "departure_port": "port_st_johns",
            "arrival_port": "port_st_johns",
            "first_activity": "STN_001",
            "last_activity": "STN_006",
            "activities": [
                "STN_001",
                "STN_002",
                "STN_003",
                "Demo_ADCP_Survey",
                "STN_004",
                "MOOR_001",
                "STN_005",
                "STN_006",
            ],
        }
    ],
}

# Save configuration
config_file = output_dir / "demo_cruise.yaml"
save_yaml(cruise_config, config_file)

print("✅ Station configuration created")
print(f"   Configuration saved to: {config_file}")
print(f"   Waypoints: {len(cruise_config['points'])}")
print(f"   Transects: {len(cruise_config['lines'])}")
print(f"   Legs: {len(cruise_config['legs'])}")
# Out:
# INFO: Saved configuration to: ../tests_output/demo/demo_cruise.yaml
# 🗺️  Creating station configuration...
# ✅ Station configuration created
#    Configuration saved to: ../tests_output/demo/demo_cruise.yaml
#    Waypoints: 7
#    Transects: 1
#    Legs: 1

# %% [markdown]
# ### Step 3.5: Manually edit configuration
#
# The cruise configuration in `stations.yaml` will have some default values that need to be manually updated.  These include the `departure_port` and `arrival_port` within the cruise leg definition.  Default values are called "port_update", but can be replaced using values from the catalog of ports.
#
# ```yaml
# legs:
#   - name: Interactive_Survey
#     departure_port: port_update
#     arrival_port: port_update
#     first_waypoint: STN_001
#     last_waypoint: STN_002
#     strategy: sequential
#     activities:
#       - STN_001
#       - STN_002
#       - Transit_01
#       - Area_01
# ```

# %%
# Using cruiseplan.schema.ports with get_available_ports() and list_ports_in_region()

ports = get_available_ports()

# Display them nicely
for port_id, description in ports.items():
    print(f"{port_id}: {description}")

# Or get ports in a specific region
north_atlantic_ports = list_ports_in_region(
    min_lat=50.0, max_lat=70.0, min_lon=-30.0, max_lon=20.0
)

for port_id, port_name in north_atlantic_ports.items():
    print(f"{port_id}: {port_name}")

# If you want to add a custom port for your project
add_custom_port(
    "port_my_station",
    {
        "name": "My Research Station",
        "display_name": "My Research Station, Location",
        "latitude": 60.0,
        "longitude": -20.0,
        "timezone": "GMT+0",
        "description": "Custom research station for this cruise",
    },
)
# Out:
# port_reykjavik: Port: Reykjavik
# port_nuuk: Port: Nuuk
# port_tromso: Port: Tromsø
# port_trondheim: Port: Trondheim
# port_bergen: Port: Bergen
# port_southampton: Port: Southampton
# port_bremerhaven: Port: Bremerhaven
# port_hamburg: Port: Hamburg
# port_emden: Port: Emden
# port_rostock: Port: Rostock
# port_kiel: Port: Kiel
# port_brest: Port: Brest
# port_nice: Port: Nice
# port_vigo: Port: Vigo
# port_cadiz: Port: Cadiz
# port_malaga: Port: Malaga
# port_heraklion: Port: Heraklion
# port_catania: Port: Catania
# port_limassol: Port: Limassol
# port_las_palmas: Port: Las Palmas
# port_ponta_delgada: Port: Ponta Delgada
# port_funchal: Port: Funchal
# port_mindelo: Port: Mindelo
# port_walvis_bay: Port: Walvis Bay
# port_durban: Port: Durban
# port_halifax: Port: Halifax
# port_st_johns: Port: St. John's
# port_vancouver: Port: Vancouver
# port_woods_hole: Port: Woods Hole
# port_san_diego: Port: San Diego
# port_astoria: Port: Astoria
# port_honolulu: Port: Honolulu
# port_ensenada: Port: Ensenada
# port_balboa: Port: Balboa
# port_bridgetown: Port: Bridgetown
# port_rio_de_janeiro: Port: Rio de Janeiro
# port_fortaleza: Port: Fortaleza
# port_belem: Port: Belem
# port_recife: Port: Recife
# port_antofagasta: Port: Antofagasta
# port_port_louis_mauritius: Port: Port Louis
# port_la_reunion: Port: La Reunion
# port_port_louis_seychelles: Port: Port Louis
# port_colombo: Port: Colombo
# port_singapore: Port: Singapore
# port_yokohama: Port: Yokohama
# port_fremantle: Port: Fremantle
# port_wellington: Port: Wellington
# port_christchurch: Port: Christchurch
# port_auckland: Port: Auckland
# port_papeete: Port: Papeete
# port_update: Port: Hamburg (DEFAULT UPDATE PLACEHOLDER)
# port_update_departure: Port: Hamburg (DEPARTURE PLACEHOLDER)
# port_update_arrival: Port: Hamburg (ARRIVAL PLACEHOLDER)
# port_reykjavik: Reykjavik
# port_tromso: Tromsø
# port_trondheim: Trondheim
# port_bergen: Bergen
# port_southampton: Southampton
# port_bremerhaven: Bremerhaven
# port_hamburg: Hamburg
# port_emden: Emden
# port_rostock: Rostock
# port_kiel: Kiel
# port_update: Hamburg (DEFAULT UPDATE PLACEHOLDER)
# port_update_departure: Hamburg (DEPARTURE PLACEHOLDER)
# port_update_arrival: Hamburg (ARRIVAL PLACEHOLDER)

# %% [markdown]
# ### Step 4: Process Configuration
#
# **CLI Equivalent**: `cruiseplan enrich -c demo_cruise.yaml --add-depths --add-coords --expand-sections`
#
# Add computed data like depths, formatted coordinates, and expand CTD sections.

# %%
# Verify the function is available
print("Type of cruiseplan.process:", type(cruiseplan.process))
print("Is callable:", callable(cruiseplan.process))
print("🔧 Processing configuration (enrich + validate + map)...")
config_file = output_dir / "demo_cruise.yaml"

try:
    process_result = cruiseplan.process(
        config_file=config_file,
        output_dir=str(output_dir),
        output="demo_cruise",
        format="png",
        bathy_source="etopo2022",
        bathy_dir="../data/bathymetry",  # Go up to project root, then into data
        bathy_stride=10,
        figsize=[12, 8],
        depth_check=True,
        tolerance=10,
    )

    # Extract data from result
    cruise_config = process_result.config
    generated_config_files = process_result.files_created

    if cruise_config:
        print("✅ Processing completed successfully!")
        print("   - Configuration enriched")
        print("   - Validation passed")
        for file in generated_config_files:
            print(f"   📄 {file!s}")
    else:
        print("❌ Processing failed")

except Exception as e:
    print(f"❌ Processing failed: {e}")
    import traceback

    traceback.print_exc()
# Out:
# INFO: 🚀 Processing cruise configuration: ../tests_output/demo/demo_cruise.yaml
# INFO: 🔧 Enriching cruise configuration...
# INFO: 🔧 Enriching /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise.yaml
# INFO: Section expansion complete: 0 sections → 0 stations
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: Added depths to 7 stations using etopo2022
# INFO: Saved configuration to: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: ✅ Configuration enriched successfully: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: ✅ Validating cruise configuration...
# INFO: 🔍 Validating /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# Type of cruiseplan.process: <class 'function'>
# Is callable: True
# 🔧 Processing configuration (enrich + validate + map)...
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: ✅ Validation passed
# INFO: 🗺️ Generating cruise maps...
# INFO: Display bounds: 44.5°-66.1°N, -57.7°--25.0°E
# INFO: Loading bathymetry for region: 41.5°-69.1°N, -60.7°--22.0°E
# INFO: ✅ Loaded bathymetry from /home/runner/work/cruiseplan/cruiseplan/data/bathymetry/ETOPO_2022_v1_60s_N90W180_bed.nc
# INFO: Added bathymetry contours covering full region
# INFO: Map displayed with 8 points, 1 lines, 0 areas
# INFO: Map saved to /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_map.png
# INFO: ✅ Processing complete! Generated 2 files
# ✅ Processing completed successfully!
#    - Configuration enriched
#    - Validation passed
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
#    📄 /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_map.png

# %% [markdown]
# ## Phase 3: Cruise scheduling + outputs
#
# ### Step 5: Generate Schedule
#
# **CLI Equivalent**: `cruiseplan schedule -c demo_cruise_enriched.yaml -o tests_output/demo/ --format all`
#
# Generate the complete cruise timeline and output files.

# %%
# Find the enriched config file from the previous step
enriched_config_file = None
for files in generated_config_files:
    if str(files).endswith("enriched.yaml"):
        enriched_config_file = files
        break

if not enriched_config_file:
    enriched_config_file = output_dir / "demo_cruise_enriched.yaml"

print("📅 Generating cruise schedule...")

try:
    # Generate the schedule with multiple output formats using new API
    schedule_result = cruiseplan.schedule(
        config_file=enriched_config_file,
        output_dir="../tests_output/demo",
        output="demo_cruise",
        format="html,csv,netcdf",
        leg=None,
        derive_netcdf=True,
    )

    # Extract data from result
    timeline = schedule_result.timeline
    generated_files = schedule_result.files_created

    print("✅ Schedule generated successfully!")
    if timeline:
        print(f"   Timeline object created with {len(timeline)} activities")
        print("   Output files in: ../tests_output/demo/")
        print("   Generated formats: HTML, CSV, NetCDF")
        for file in generated_files:
            print(f"   - {file}")

    else:
        print("⚠️ No timeline generated")

except Exception as e:
    print(f"❌ Schedule generation failed: {e}")
    # Optionally show the full traceback for debugging
    import traceback

    traceback.print_exc()
# Out:
# INFO: 📅 Generating schedule from /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_enriched.yaml
# INFO: 🌐 HTML Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
# INFO:    Timeline contains 19 activities
# INFO:    Adding to ports: St. John's (activity=Port, op_class=PointOperation, op_type=port)
# INFO:    Adding to stations: STN_001 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to stations: STN_002 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to stations: STN_003 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to scientific_transits: Demo_ADCP_Survey (activity=Line, op_class=LineOperation, op_type=underway)
# INFO:    Adding to stations (other): STN_004 (activity=Station, op_class=PointOperation, op_type=water_sampling)
# INFO:    Adding to moorings: MOOR_001 (activity=Mooring, op_class=PointOperation, op_type=mooring)
# INFO:    Adding to stations: STN_005 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to stations: STN_006 (activity=Station, op_class=PointOperation, op_type=CTD)
# INFO:    Adding to ports: St. John's (activity=Port, op_class=PointOperation, op_type=port)
# INFO: 🔍 Cruise-level operation counts:
# INFO:    Stations: 6
# INFO:    Moorings: 1
# INFO:    Scientific transits (surveys): 1
# INFO:    Area operations: 0
# INFO:    Total scientific operations: 8
# INFO:    Port activities: 2
# INFO:    Within-area transits: 7
# INFO: 🔍 Leg 'Demo_Survey' operation counts:
# INFO:    Stations: 5
# INFO:    Moorings: 1
# INFO:    Surveys: 1
# INFO:    Areas: 0
# INFO:    Total scientific operations: 8
# INFO:    Total activities in leg: 19
# INFO: ✅ Generated HTML schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
# INFO: 📊 CSV Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
# INFO:    Timeline contains 19 activities
# INFO: ✅ Generated CSV schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
# INFO: 📄 NetCDF Generator: Starting generation of /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO:    Timeline contains 19 activities
# INFO: ✅ Generated NetCDF schedule: /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc
# INFO: 📅 Schedule generation complete! Generated 3 files
# 📅 Generating cruise schedule...
# ✅ Schedule generated successfully!
#    Timeline object created with 19 activities
#    Output files in: ../tests_output/demo/
#    Generated formats: HTML, CSV, NetCDF
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.html
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.csv
#    - /home/runner/work/cruiseplan/cruiseplan/tests_output/demo/demo_cruise_schedule.nc

# %%
# Find the *.nc file in generated_files list of paths (from schedule result)
schedule_file = None
for file in generated_files:
    if str(file).endswith(".nc"):
        schedule_file = file
        break

if schedule_file:
    ds = xr.open_dataset(schedule_file)
    ds
else:
    print("No NetCDF file found in generated files")

# %%
ds
# Out:
# <xarray.Dataset> Size: 11kB
# Dimensions:           (obs: 19)
# Coordinates:
#     time              (obs) datetime64[ns] 152B ...
#     longitude         (obs) float32 76B ...
#     latitude          (obs) float32 76B ...
#     water_depth       (obs) float32 76B ...
# Dimensions without coordinates: obs
# Data variables: (12/20)
#     operation_depth   (obs) float32 76B ...
#     name              (obs) <U27 2kB ...
#     category          (obs) <U15 1kB ...
#     type              (obs) <U14 1kB ...
#     action            (obs) <U10 760B ...
#     comment           (obs) <U25 2kB ...
#     ...                ...
#     exit_latitude     (obs) float32 76B ...
#     exit_longitude    (obs) float32 76B ...
#     end_time          (obs) datetime64[ns] 152B ...
#     dist_nm           (obs) float32 76B ...
#     activity          (obs) <U7 532B ...
#     operation_class   (obs) <U19 1kB ...
# Attributes:
#     featureType:          trajectory
#     title:                Ship Schedule: Demo North Atlantic Survey 2025
#     institution:          Generated by CruisePlan software
#     source:               Scheduler computation from YAML configuration
#     Conventions:          CF-1.8
#     cruise_name:          Demo North Atlantic Survey 2025
#     total_duration_days:  16.279997299965277
#     creation_date:        2026-08-04T14:17:38
#     comment:              Master file containing all cruise data - specialize...

# %% [markdown]
# ## Workflow Summary
#
# Let's review what we've accomplished and check our output files.

# %%
all_files = pangaea_files + [config_file] + generated_config_files + generated_files

print("✅ CruisePlan Demo Complete!")
print(f"📁 Generated files: {len(all_files)} files in {Path(output_dir).name}/")
for file in all_files:
    print(f"   📄 {file.name}")
# Out:
# ✅ CruisePlan Demo Complete!
# 📁 Generated files: 8 files in demo/
#    📄 demo_dois.txt
#    📄 demo.pkl
#    📄 demo_cruise.yaml
#    📄 demo_cruise_enriched.yaml
#    📄 demo_cruise_map.png
#    📄 demo_cruise_schedule.html
#    📄 demo_cruise_schedule.csv
#    📄 demo_cruise_schedule.nc
